# %% [markdown]
# # Analyze Improvement

# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import TensorDataset, DataLoader

RANDOM_SEED=1

def set_random_seed_data(seed):
    RANDOM_SEED = seed

def lowercase(text):
    return text.lower()

def remove_nonaplhanumeric(text):
    text = re.sub('[^0-9a-zA-Z]+', ' ', text) 
    return text

def remove_unnecessary_char(text):
    text = re.sub('\n',' ',text) # Remove every '\n'
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+)|(http?://[^\s]+))',' ',text) # Remove every URL
    text = re.sub('  +', ' ', text) # Remove extra spaces
    text = text.strip()
    return text

def preprocess_text(text):
    text = lowercase(text)
    text = remove_nonaplhanumeric(text)
    text = remove_unnecessary_char(text)
    return text

def load_data(PATH):
    data = pd.read_csv(PATH)
    data['label'] = ((data['HS'] == 1) | (data['Abusive'] == 1)).apply(lambda x: int(x))
    data = data[['Tweet', 'label']]
    data = data.rename(columns={'Tweet': 'text'})

    X_train, X_test, y_train, y_test = train_test_split(data.text.values, 
                                                        data.label.values, 
                                                        test_size=0.1,
                                                        random_state=RANDOM_SEED,
                                                        stratify=data.label.values)
    train = pd.DataFrame({'text': X_train,
                          'label': y_train})

    test = pd.DataFrame({'text': X_test,
                         'label': y_test})
    
    return test

# %%
test = load_data('../../../../../data/toxic/preprocessed_indonesian_toxic_tweet.csv')
test.head()
# Out:
#                                                 text  label
# 0  gubernur daerah khusus ibukota salat jumat ber...      0
# 1   hindu tidak mengenal hari persidangan hindu p...      0
# 2                                     jancuk jancuk       1
# 3                bukti on bukti jangan congor doang       1
# 4  19 akhirnya adalah khilafah yang ditempuh deng...      1

# %% [markdown]
# # Improvement

# %%
data = pd.read_csv('result_toxic_toxic_XLM_R_A_11852_0.5_full.csv')
data['y_pred_int'] = data['y_pred'].apply(lambda x: int(x>=0.5))
data.head()
# Out:
#      y_pred  y_true  y_pred_int
# 0  0.039386       0           0
# 1  0.032706       0           0
# 2  0.905435       1           1
# 3  0.980905       1           1
# 4  0.126742       1           0

# %%
data_improve = pd.read_csv('result_toxic_toxic_XLM_R_C_11852_3_full.csv')
data_improve['y_pred_int'] = data_improve['y_pred'].apply(lambda x: int(x>=0.5))
data_improve.head()
# Out:
#      y_pred  y_true  y_pred_int
# 0  0.004836       0           0
# 1  0.002019       0           0
# 2  0.999285       1           1
# 3  0.987206       1           1
# 4  0.188467       1           0

# %%
data['text'] = test['text'].values
data['y_pred_improve'] = data_improve['y_pred'].values
data['y_pred_improve_int'] = data_improve['y_pred_int']
data.head()
# Out:
#      y_pred  y_true  y_pred_int  \
# 0  0.039386       0           0
# 1  0.032706       0           0
# 2  0.905435       1           1
# 3  0.980905       1           1
# 4  0.126742       1           0
#
#                                                 text  y_pred_improve  \
# 0  gubernur daerah khusus ibukota salat jumat ber...        0.004836
# 1   hindu tidak mengenal hari persidangan hindu p...        0.002019
# 2                                     jancuk jancuk         0.999285
# 3                bukti on bukti jangan congor doang         0.987206
# 4  19 akhirnya adalah khilafah yang ditempuh deng...        0.188467
#
#    y_pred_improve_int
# 0                   0
# 1                   0
# 2                   1
# 3                   1
# 4                   0

# %%
count_pos = 0
count_neg = 0
for i in range(0, data.shape[0]):
    if (data.loc[i].y_pred_int != data.loc[i].y_true) and (data.loc[i].y_pred_improve_int == data.loc[i].y_true) and (data.loc[i].y_true == 1):
        if data.loc[i].y_true == 1:
            count_pos +=1
        else:
            count_neg += 1
            
        print("\ny_pred: {}".format(data.loc[i].y_pred))
        print("y_true: {}".format(data.loc[i].y_true))        
        print("y_pred_improve: {}".format(data.loc[i].y_pred_improve))        
        print("text: {}".format(data.loc[i].text))
# Out:
# y_pred: 0.41355938
# y_true: 1
# y_pred_improve: 0.9799235000000001
# text:  pasti ada yang bacot begini meminta ganti mantel lah mantel kan banyak tinggal beli dan masalahnya mantel itu mantel yang jumlah xe2 x80 xa6
#
# y_pred: 0.074108094
# y_true: 1
# y_pred_improve: 0.8050988
# text: suasana stq tingkat kabupaten tidak ada ntt cukup dalam masjid tanpa mimbar tanpa dana swasembada dari umat islam untuk bawa nama pemerintah daerah dalam musabaqah tilawatil quran ke tingkat propinsi ntt menyedihkan 2019 ganti presiden
#
# y_pred: 0.42839316
# y_true: 1
# y_pred_improve: 0.6419626
# text: selama proses sidang ahok mewaspadai ulama ulama kubu ahok yakni ulama ulama munafik yang sesat dan menyesatkan
#
# y_pred: 0.25542468
# y_true: 1
# y_pred_improve: 0.5927736
# text: apalagi yang paling bermasalah dengan partai komunis indonesia itu ya angkatan darat cukup dengan menggerakkan massa anti jokowi dengan isu isu anti agama komunis
#
# y_pred: 0.3151176
# y_true: 1
# y_pred_improve: 0.88784593
# text: sompret sekali lagi enak enak tiduran tiba tiba hujan harus memasukkan jemuran eh 5 menit kemudian terang lagi ingin berkata halus xf0 x9f x98 xb2 xf0 x9f x98 xb2 xf0 x9f x98 xb2
#
# y_pred: 0.07197806
# y_true: 1
# y_pred_improve: 0.58060175
# text:  lagi dik sorbejeh aku cak macetnya edan edanan persebaya sama arema dino minggu timnas kayaknya lak menukarkan tiket iya masih h
#
# y_pred: 0.29793686
# y_true: 1
# y_pred_improve: 0.50695306
# text: 3 kelompok di balik rezim ini merekayasa berbagai terorisme islam untuk merusak citra islam dan indonesia 4 menuduh umat islam indonesia militan radikal garis keras 5 menyudutkan islam melalui berbagai isu sepe i lgbt dan lain lain 6 menuduh mencurigai i
#
# y_pred: 0.13876039
# y_true: 1
# y_pred_improve: 0.9871181999999998
# text: update status bikin tugas tugas selesai tidak ya kok jancuk sekali jembut
#
# y_pred: 0.15734744
# y_true: 1
# y_pred_improve: 0.8009337
# text: secara tak sengaja baju jokowi memecah indonesia jadi dua bagian menyedihkannya presiden yang tak paham ideologi amp konstitusi negara kesatuan republik indonesia by chirpstory
#
# y_pred: 0.08131024
# y_true: 1
# y_pred_improve: 0.51806766
# text: habis kerja pukul 11 sampai sekarang tk balik rumah nasib bujang kalau sudah kawin mampus bini aku sangsi kata aku tidak rumah bini no 2 haha
#
# y_pred: 0.03677064
# y_true: 1
# y_pred_improve: 0.8108714
# text:  dua periode impo beras garam jagung dan lain lain dan dua periode pengangguran tenaga kerja asing menyerbu indonesia dan dua periode ulama habib dikasari dizalimi kepada tuan guru cabul jangan hanya pakai otak guna kan juga apa
#
# y_pred: 0.27222294
# y_true: 1
# y_pred_improve: 0.993449
# text: on the way jakarta wusssstt turunkan jokowi
#
# y_pred: 0.15279820000000002
# y_true: 1
# y_pred_improve: 0.8637947
# text:  kayaknya sih abu janda yang jadi event organizer acara deklarasi ulama muda ini kemarin sih faizal assegaf yang be indak jadi event organizer nya dalam aksi aktivis 98 palsunya besok besok lagi mungkin ada pula deklarasi lgbt deklarasi cebong dukung mukidi dan seterusnya pada kenyang
#
# y_pred: 0.35102665
# y_true: 1
# y_pred_improve: 0.95595455
# text: puisi kampungan sudahlah bodoh ilmu dunia bodoh pula ilmu agamanya innalillahi
#
# y_pred: 0.33006483
# y_true: 1
# y_pred_improve: 0.88013375
# text: memaki gue monyet tetapi mt gue di love wkwk uniform resource locator
#
# y_pred: 0.029850900000000003
# y_true: 1
# y_pred_improve: 0.5027374
# text:  percaya muhammad nabi silakan asal tak rugikan yang lain karena ada bom negara wajib ungkap siapa muhammad
#
# y_pred: 0.4474321
# y_true: 1
# y_pred_improve: 0.9970515999999999
# text: sebenarnya pacar gue itu 12 idiot
#
# y_pred: 0.1147683
# y_true: 1
# y_pred_improve: 0.9431006
# text:  kalau ada yang percaya nenek peot yang satu ini bera i otaknya sudah dungu kenapa masalah peraturan presiden no 20 tahun 2018 tentang tenaga kerja asing diributkan baca yang lengkap siapa yang berpihak dan siapa yang tidak berpihak
#
# y_pred: 0.48667336
# y_true: 1
# y_pred_improve: 0.9404251
# text:  dia budek buta dan otak mati jadi mungkin sulit jangan berharap banyak
#
# y_pred: 0.033949465
# y_true: 1
# y_pred_improve: 0.6222454000000001
# text: asmara pujangga kere dengan jablay asuransi garap sawah ayo wkwk
#
# y_pred: 0.34628418
# y_true: 1
# y_pred_improve: 0.9972979
# text: badan eksekutif mahasiswa paling kampret memang tertawa sampai besok xf0 x9f xa4 xa3 xf0 x9f xa4 xa3 xf0 x9f xa4 xa3 xf0 x9f xa4 xa3 xf0 x9f xa4 xa3 xf0 x9f xa4 xa3 xf0 x9f xa4 xa3 xf0 x9f xa4 xa3 xf0 x9f xa4 xa3 uniform resource locator
#
# y_pred: 0.48602244
# y_true: 1
# y_pred_improve: 0.8527918
# text:  putra daerah pada kemana masa siliwangi mau di ganti ondel ondel pak serius
#
# y_pred: 0.30165770000000003
# y_true: 1
# y_pred_improve: 0.71990144
# text:  pada jamilah ih aisya nya lesbi xf0 x9f x98 x83 ioixonemakrab
#
# y_pred: 0.26701364
# y_true: 1
# y_pred_improve: 0.9791337
# text: harga minyak dunia west texas intermediate sudah 71 dan berhenti sudah 81 asumsi pemerintah 48 dan direksi pe amina sudah ganti berkali kali di pemerintahan jokowi kasihan perusahaan ini buat mainan politikus kacrut
#
# y_pred: 0.07504547
# y_true: 1
# y_pred_improve: 0.99535334
# text: kalau ada masjid yang lebih tua dari candi candi milik kerajaan hindu buddha di nusantara ini baru kalian boleh usir cina kalau tidak kalian cuma pendatang
#
# y_pred: 0.31423223
# y_true: 1
# y_pred_improve: 0.9816748
# text:  wkwk bangkai sambil ada yang mengetuk di jendela
#
# y_pred: 0.24295011
# y_true: 1
# y_pred_improve: 0.8896609000000001
# text:  wkwk padahal yang sering main klaim program dan hasil kerja orang lain ya dia saudari dan pendukung pendukung nya uniform resource locator
#
# y_pred: 0.38754147
# y_true: 1
# y_pred_improve: 0.9924978000000001
# text:  hai setan semua operator tri jawabannya sama banyaknya antusiasme sekarang masalahnya masuk pun tidak bisa menunggu 1 jam tidak di angkat barangkali pingsan semua
#
# y_pred: 0.26094306
# y_true: 1
# y_pred_improve: 0.72804236
# text: direct message gue tidak dibalas tai pulsa hilang oi 70r
#
# y_pred: 0.03591779
# y_true: 1
# y_pred_improve: 0.9261372
# text: 19 pemimpin dari masjid adalah pemimpin yang dapat mengajak kita untuk menjalankan syariat islam secara sungguh sungguh jatuhkan pemimpin non muslim
#
# y_pred: 0.41784412
# y_true: 1
# y_pred_improve: 0.9532995000000001
# text: selalu ingat km bukan siapa siapa bukan apa apa jadi tidak ada pentingnya juga buat kamu tau dan nbut i need belong to someone haha agony of loneliness huh teori nya pak kassin lagi nih geblek
#
# y_pred: 0.48074588
# y_true: 1
# y_pred_improve: 0.88327515
# text: apakah ini beradab jika setuju tidak beradab buang islam karena hanya dengan buang islam kebiadaban dapat dikurangi
#
# y_pred: 0.42612693
# y_true: 1
# y_pred_improve: 0.99810266
# text:  antre dari jam 02 00 edan bonek xf0 x9f x98 x82 xf0 x9f x98 x82 xf0 x9f x98 x82
#
# y_pred: 0.064238966
# y_true: 1
# y_pred_improve: 0.95925283
# text: setelah itu expect boleh lepas tangan semua kerja yang lecturer bagi ape lancau sial cina nih
#
# y_pred: 0.3383083
# y_true: 1
# y_pred_improve: 0.5840008000000001
# text: alumni sekte togel banyak kena gangguan jiwa karma
#
# y_pred: 0.08789712
# y_true: 1
# y_pred_improve: 0.8419690000000001
# text:  anjir dan gue mengecek berkali kali buat memastikan itu cewek benaran apa cowok siapa tau tipuan kayak video yang lain ternyata asli cewek xf0 x9f x98 xad dan terlepas dari gender tetap enggak benar sih astaga xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad xf0 x9f x98 xad semoga adek gue tidak begini amin
#
# y_pred: 0.042122066
# y_true: 1
# y_pred_improve: 0.876287
# text:  indonesia sedang di jajah cina
#
# y_pred: 0.40606820000000005
# y_true: 1
# y_pred_improve: 0.9866089
# text: suasana hati kerja berubah karena nih banci xf0 x9f x98 x8e xf0 x9f x98 xa3 xf0 x9f x98 xa3 xf0 x9f x98 xa3
#
# y_pred: 0.035535514
# y_true: 1
# y_pred_improve: 0.98958963
# text: di pilihan kepala daerah daerah khusus ibukota 2017 yang didengungkan soal agama tapi dipemilihan presiden sekarang yang didengungkan ganti presiden sampai sampai di takjil dilabeli ganti presiden dasar munafik
#
# y_pred: 0.07784450000000001
# y_true: 1
# y_pred_improve: 0.5456441999999999
# text:  pak cik sudah tua nak apalah kuadrat pak cik nih boleh buat sepakat pakai kopiah meminta sedekah jual kismis dan dan pak cik muda lagi bila pak cik warna rambut kuning bawa duit perbanyak dan dan kita oke kan dan nini adalah anjing begitu begitu begitu xf0 x9f x90 xbc xf0 x9f x90 xbc xf0 x9f x90
#
# y_pred: 0.43602002
# y_true: 1
# y_pred_improve: 0.9843905999999999
# text:  bro anda punya wewenang di dewan perwakilan rakyat untuk bentuk panitia khusus atau apalah ambil action dong cocot saja di twitter
#
# y_pred: 0.0349198
# y_true: 1
# y_pred_improve: 0.9806700999999999
# text:  itu kan dungu kalau km make gelang itu dan ada di tempat kejadian perkara ikut intimidasi secara langsung km terlibat gelang itu baru dugaan sebagai bentuk konspirasi
#
# y_pred: 0.039949536
# y_true: 1
# y_pred_improve: 0.855723
# text: sudah tau gue bakal war masalah jubah jubahan cukup menyimak saja lah ya kyungsoo sama taehyung bias gue bagaimana gue bisa war kampang
#
# y_pred: 0.11936602
# y_true: 1
# y_pred_improve: 0.5827916999999999
# text:  keluarga halilintar hem masa km tak tau udik
#
# y_pred: 0.1783118
# y_true: 1
# y_pred_improve: 0.6094343000000001
# text: tentara nasional indonesia menyerukan menonton tiga puluh detik karena pemerintah sekarang pro komunis partai komunis indonesia
#
# y_pred: 0.15169722
# y_true: 1
# y_pred_improve: 0.6689991999999999
# text:  terang benderang boediono berkeinginan menjadi wakil presiden saat itu zalimnya dia membohongi rakyat bahkan anak buahnya dengan menutupi seakan ekonomi indonesia pasti runtuh jika tidak menyelamatkan bank century bung rr ba

# %%
print(count_pos,
count_neg)
# Out:
# 46 36

# %%
count_pos+count_neg
# Out:
# 82
