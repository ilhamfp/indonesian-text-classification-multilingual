# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure,xticks,yticks
# %matplotlib inline

DATA_DIR = '.'

# %%
data = pd.concat([
    pd.read_csv('./trip_advisor/mbert/gains.csv'),
    pd.read_csv('./toxic/mbert/gains.csv'),
    pd.read_csv('./prosa/mbert/gains.csv')
])
data.head(20)
# Out:
#     data      gain
# 0    500  0.054725
# 1   1000  0.037482
# 2   2500  0.070896
# 3   5000  0.042598
# 4   7500  0.047193
# 5  10000  0.040038
# 0    500  0.160564
# 1   1000  0.178234
# 2   2500  0.000000
# 3   5000  0.000000
# 4   7500  0.000000
# 5  10000  0.000000
# 0    500  0.172894
# 1   1000  0.111931
# 2   2500  0.082783
# 3   5000  0.046093
# 4   7500  0.036936
# 5  10000  0.020515

# %%
data.data.values
# Out:
# array([  500,  1000,  2500,  5000,  7500, 10000,   500,  1000,  2500,
#         5000,  7500, 10000,   500,  1000,  2500,  5000,  7500, 10000],
#       dtype=int64)

# %%
data = data.sort_values(by=['data'])
data.head(20)
# Out:
#     data      gain
# 0    500  0.054725
# 0    500  0.172894
# 0    500  0.160564
# 1   1000  0.037482
# 1   1000  0.111931
# 1   1000  0.178234
# 2   2500  0.082783
# 2   2500  0.000000
# 2   2500  0.070896
# 3   5000  0.000000
# 3   5000  0.042598
# 3   5000  0.046093
# 4   7500  0.036936
# 4   7500  0.000000
# 4   7500  0.047193
# 5  10000  0.000000
# 5  10000  0.040038
# 5  10000  0.020515

# %%
data_mean = data.groupby(['data']).mean()
data_mean = data_mean.reset_index()
data_mean.head(10)
# Out:
#     data      gain
# 0    500  0.129394
# 1   1000  0.109215
# 2   2500  0.051226
# 3   5000  0.029564
# 4   7500  0.028043
# 5  10000  0.020184

# %%
data = data_mean
data.head(10)
# Out:
#     data      gain
# 0    500  0.129394
# 1   1000  0.109215
# 2   2500  0.051226
# 3   5000  0.029564
# 4   7500  0.028043
# 5  10000  0.020184

# %%
data.data.values
# Out:
# array([  500,  1000,  2500,  5000,  7500, 10000], dtype=int64)

# %%
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')


# plt.plot(data.gain.values,
#          data.data.values
#         )

plt.plot(data.data.values,
         data.gain.values
        )

xticks([1000,  2500,  5000,  7500, 10000], [1000,  2500,  5000,  7500, 'MAX'])
# plt.legend(loc="upper right")
plt.xlabel('Banyak data bahasa Indonesia')
plt.ylabel('Rata-rata perbedaan F1-score baseline dengan hasil tertinggi')
plt.title('')
plt.savefig('plot_mbert.png')
plt.show()
