# %% [markdown]
# # IndoXTC - Fine-tune Head TripAdvisor [XLM-R] [ALL]
# Exploring Indonesian hate speech/abusive & sentiment text classification using multilingual language model.
#
# This kernel is a part of my undergraduate final year project.
# Checkout the full github repository:
# https://github.com/ilhamfp/indonesian-text-classification-multilingual

# %%
#############################
# Experiment configurations #
#############################

INDO_DATA_NAME = 'trip_advisor'
DATA_PATH_INDO = '../input/indoxtc-extracting-tripadvisor-features-xlm-r'

FOREIGN_DATA_NAME = 'yelp'
DATA_PATH_FOREIGN = '../input/indoxtc-combining-yelp-features-xlm-r'

MODEL_NAME = 'XLM_R'

EXPERIMENT_TYPE_LIST = ['A', 'B', 'C'] # A / B / C
TOTAL_DATA_LIST = [500, 1000, 2500, 5000, 7500, 12389]
FOREIGN_LANG_DATA_MULT_LIST = [0.25, 0.5, 0.75, 1, 1.5, 2, 3, 4, 5, 6, 7, 8, 9, 10]
RANDOM_SEED_LIST = [4,5,6]
VALIDATION_DATA = 0.1

# %%
import os
import numpy as np
import pandas as pd
from load_data import load_experiment_features, set_random_seed_data
from model_head import set_seed, train, test, evaluate
# Out:
# CUDA is not available.  Training on CPU ...

# %% [markdown]
# ## Experiment

# %%
result_list_final = []
for RANDOM_SEED in RANDOM_SEED_LIST:
    print("\n############################")
    print("### START RANDOM_SEED {} ###".format(RANDOM_SEED))
    print("############################")
    result_list = []
    for TOTAL_DATA in TOTAL_DATA_LIST:
        print("\n##### TOTAL_DATA {} #####".format(TOTAL_DATA))

        for EXPERIMENT_TYPE in EXPERIMENT_TYPE_LIST:
            for FOREIGN_LANG_DATA_MULT in FOREIGN_LANG_DATA_MULT_LIST:
                set_seed(seed=RANDOM_SEED)
                set_random_seed_data(seed=RANDOM_SEED)
                if EXPERIMENT_TYPE != 'C':
                    print('\n~~Result_{}_{}~~'.format(EXPERIMENT_TYPE,
                                                       TOTAL_DATA))
                else:
                    print('\n~~Result_{}_{}_{}~~'.format(EXPERIMENT_TYPE,
                                                   TOTAL_DATA,
                                                   FOREIGN_LANG_DATA_MULT))

                train_loader, valid_loader, test_loader = load_experiment_features(DATA_PATH_INDO,
                                                                                   DATA_PATH_FOREIGN,
                                                                                   tipe=EXPERIMENT_TYPE, 
                                                                                   total_data=TOTAL_DATA, 
                                                                                   foreign_mult=FOREIGN_LANG_DATA_MULT,
                                                                                   valid_size=VALIDATION_DATA)

                train(train_loader, valid_loader, learning_rate=0.0001)
                print("## Test phase...")
                y_true, y_pred_proba = test(test_loader)
                max_f1, max_recall, max_precision, max_threshold = evaluate(y_true, 
                                                                            y_pred_proba,
                                                                            threshold=0.5)

                result = pd.DataFrame({
                    'y_true': y_true,
                    'y_pred_proba': y_pred_proba
                })
                
                OUTPUT_FOREIGN_LANG_DATA_MULT = FOREIGN_LANG_DATA_MULT
                if EXPERIMENT_TYPE == 'A':
                    OUTPUT_FOREIGN_LANG_DATA_MULT = 0
                elif EXPERIMENT_TYPE == 'B':
                    OUTPUT_FOREIGN_LANG_DATA_MULT = -1
                
                OUTPUT_TOTAL_FOREIGN_DATA = int(TOTAL_DATA*FOREIGN_LANG_DATA_MULT)
                if EXPERIMENT_TYPE == 'A':
                    OUTPUT_TOTAL_FOREIGN_DATA = 0
                elif EXPERIMENT_TYPE == 'B':
                    OUTPUT_TOTAL_FOREIGN_DATA = TOTAL_DATA

                result_list.append({
                    'type':EXPERIMENT_TYPE,
                    'total_data':TOTAL_DATA, 
                    'seed':RANDOM_SEED,
                    'foreign_mult':OUTPUT_FOREIGN_LANG_DATA_MULT,
                    'total_foreign_data':OUTPUT_TOTAL_FOREIGN_DATA,
                    'f1':max_f1,
                    'recall':max_recall,
                    'precision':max_precision
                })

                os.remove("model.pt")

                if EXPERIMENT_TYPE != 'C':
                    break
                    
    final_result = pd.DataFrame(result_list) 
    final_result = final_result.sort_values(by=['total_data', 'foreign_mult'])
    final_result.to_csv('final_{}_{}_{}_result_combined_seed_{}.csv'.format(INDO_DATA_NAME,
                                                                           FOREIGN_DATA_NAME,
                                                                           MODEL_NAME,
                                                                           RANDOM_SEED),
                        index=False)
    
    result_list_final.extend(result_list)
# Out:
# ############################
# ### START RANDOM_SEED 4 ###
# ############################
#
# ##### TOTAL_DATA 500 #####
#
# ~~Result_A_500~~
# EarlyStopping! Epoch 36
# Last: 23 	T-Loss: 0.682547 	T-Acc: 0.664444 	V-Loss: 0.673167 	V-Acc: 0.620000
# ## Test phase...
# Final test Loss: 0.690155
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.51678565 	Recall: 0.82044444 	Prec: 0.50217628
#
# ~~Result_B_500~~
# EarlyStopping! Epoch 36
# Last: 23 	T-Loss: 0.689532 	T-Acc: 0.548889 	V-Loss: 0.677213 	V-Acc: 0.500000
# ## Test phase...
# Final test Loss: 0.694628
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46409262 	Recall: 0.66755556 	Prec: 0.45460048
#
# ~~Result_C_500_0.25~~
# EarlyStopping! Epoch 43
# Last: 30 	T-Loss: 0.674175 	T-Acc: 0.655417 	V-Loss: 0.668412 	V-Acc: 0.660000
# ## Test phase...
# Final test Loss: 0.684803
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.59499497 	Recall: 0.76000000 	Prec: 0.54878049
#
# ~~Result_C_500_0.5~~
# EarlyStopping! Epoch 27
# Last: 14 	T-Loss: 0.684573 	T-Acc: 0.613333 	V-Loss: 0.679297 	V-Acc: 0.560000
# ## Test phase...
# Final test Loss: 0.690530
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.51355265 	Recall: 0.82577778 	Prec: 0.50107875
#
# ~~Result_C_500_0.75~~
# EarlyStopping! Epoch 33
# Last: 20 	T-Loss: 0.685526 	T-Acc: 0.576142 	V-Loss: 0.675161 	V-Acc: 0.620000
# ## Test phase...
# Final test Loss: 0.688530
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.59162799 	Recall: 0.70844444 	Prec: 0.54701441
#
# ~~Result_C_500_1~~
# EarlyStopping! Epoch 29
# Last: 16 	T-Loss: 0.684555 	T-Acc: 0.615556 	V-Loss: 0.678510 	V-Acc: 0.620000
# ## Test phase...
# Final test Loss: 0.689432
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.55184752 	Recall: 0.79022222 	Prec: 0.51957919
#
# ~~Result_C_500_1.5~~
# EarlyStopping! Epoch 22
# Last: 9 	T-Loss: 0.687694 	T-Acc: 0.594667 	V-Loss: 0.681312 	V-Acc: 0.640000
# ## Test phase...
# Final test Loss: 0.692048
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48282825 	Recall: 0.84444444 	Prec: 0.48868313
#
# ~~Result_C_500_2~~
# EarlyStopping! Epoch 42
# Last: 29 	T-Loss: 0.675262 	T-Acc: 0.631852 	V-Loss: 0.675912 	V-Acc: 0.580000
# ## Test phase...
# Final test Loss: 0.686109
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58331415 	Recall: 0.77777778 	Prec: 0.54012346
#
# ~~Result_C_500_3~~
# EarlyStopping! Epoch 61
# Last: 48 	T-Loss: 0.662674 	T-Acc: 0.646667 	V-Loss: 0.667214 	V-Acc: 0.660000
# ## Test phase...
# Final test Loss: 0.679404
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61172051 	Recall: 0.77066667 	Prec: 0.56189242
#
# ~~Result_C_500_4~~
# EarlyStopping! Epoch 57
# Last: 44 	T-Loss: 0.645674 	T-Acc: 0.676889 	V-Loss: 0.651161 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.664734
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63400477 	Recall: 0.68622222 	Prec: 0.59021407
#
# ~~Result_C_500_5~~
# EarlyStopping! Epoch 77
# Last: 64 	T-Loss: 0.628747 	T-Acc: 0.699259 	V-Loss: 0.635650 	V-Acc: 0.660000
# ## Test phase...
# Final test Loss: 0.646289
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.65398813 	Recall: 0.68088889 	Prec: 0.61427426
#
# ~~Result_C_500_6~~
# EarlyStopping! Epoch 88
# Last: 75 	T-Loss: 0.620084 	T-Acc: 0.708254 	V-Loss: 0.634093 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.640714
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.66588579 	Recall: 0.69066667 	Prec: 0.62661290
#
# ~~Result_C_500_7~~
# EarlyStopping! Epoch 68
# Last: 55 	T-Loss: 0.634765 	T-Acc: 0.700833 	V-Loss: 0.639684 	V-Acc: 0.740000
# ## Test phase...
# Final test Loss: 0.654414
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.65083537 	Recall: 0.71555556 	Prec: 0.60390098
#
# ~~Result_C_500_8~~
# EarlyStopping! Epoch 52
# Last: 39 	T-Loss: 0.654732 	T-Acc: 0.657284 	V-Loss: 0.661330 	V-Acc: 0.660000
# ## Test phase...
# Final test Loss: 0.674076
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62016563 	Recall: 0.78400000 	Prec: 0.56829897
#
# ~~Result_C_500_9~~
# EarlyStopping! Epoch 80
# Last: 67 	T-Loss: 0.616016 	T-Acc: 0.718444 	V-Loss: 0.623995 	V-Acc: 0.740000
# ## Test phase...
# Final test Loss: 0.639061
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.67472882 	Recall: 0.71733333 	Prec: 0.63096169
#
# ~~Result_C_500_10~~
# EarlyStopping! Epoch 76
# Last: 63 	T-Loss: 0.593284 	T-Acc: 0.739394 	V-Loss: 0.599753 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.617442
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.69874246 	Recall: 0.72000000 	Prec: 0.66068515
#
# ##### TOTAL_DATA 1000 #####
#
# ~~Result_A_1000~~
# EarlyStopping! Epoch 57
# Last: 44 	T-Loss: 0.645274 	T-Acc: 0.725556 	V-Loss: 0.659499 	V-Acc: 0.660000
# ## Test phase...
# Final test Loss: 0.674789
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60507743 	Recall: 0.72711111 	Prec: 0.55798090
#
# ~~Result_B_1000~~
# EarlyStopping! Epoch 54
# Last: 41 	T-Loss: 0.670575 	T-Acc: 0.621111 	V-Loss: 0.679342 	V-Acc: 0.590000
# ## Test phase...
# Final test Loss: 0.699233
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.37720656 	Recall: 0.94222222 	Prec: 0.46716615
#
# ~~Result_C_1000_0.25~~
# EarlyStopping! Epoch 20
# Last: 7 	T-Loss: 0.682490 	T-Acc: 0.631111 	V-Loss: 0.674719 	V-Acc: 0.630000
# ## Test phase...
# Final test Loss: 0.692291
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.43359650 	Recall: 0.88266667 	Prec: 0.47466539
#
# ~~Result_C_1000_0.5~~
# EarlyStopping! Epoch 71
# Last: 58 	T-Loss: 0.639043 	T-Acc: 0.706667 	V-Loss: 0.647540 	V-Acc: 0.710000
# ## Test phase...
# Final test Loss: 0.662552
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63506710 	Recall: 0.66222222 	Prec: 0.59552358
#
# ~~Result_C_1000_0.75~~
# EarlyStopping! Epoch 108
# Last: 95 	T-Loss: 0.606577 	T-Acc: 0.710476 	V-Loss: 0.620606 	V-Acc: 0.670000
# ## Test phase...
# Final test Loss: 0.640234
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.65523050 	Recall: 0.68266667 	Prec: 0.61538462
#
# ~~Result_C_1000_1~~
# EarlyStopping! Epoch 53
# Last: 40 	T-Loss: 0.642231 	T-Acc: 0.691111 	V-Loss: 0.644522 	V-Acc: 0.690000
# ## Test phase...
# Final test Loss: 0.665621
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62617848 	Recall: 0.68000000 	Prec: 0.58263519
#
# ~~Result_C_1000_1.5~~
# EarlyStopping! Epoch 71
# Last: 58 	T-Loss: 0.639959 	T-Acc: 0.684444 	V-Loss: 0.643089 	V-Acc: 0.640000
# ## Test phase...
# Final test Loss: 0.663441
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63188735 	Recall: 0.69600000 	Prec: 0.58651685
#
# ~~Result_C_1000_2~~
# EarlyStopping! Epoch 90
# Last: 77 	T-Loss: 0.637870 	T-Acc: 0.689630 	V-Loss: 0.637219 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.659843
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63686539 	Recall: 0.69600000 	Prec: 0.59183673
#
# ~~Result_C_1000_3~~
# EarlyStopping! Epoch 59
# Last: 46 	T-Loss: 0.634250 	T-Acc: 0.696389 	V-Loss: 0.630702 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.652377
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64962631 	Recall: 0.69244444 	Prec: 0.60669782
#
# ~~Result_C_1000_4~~
# EarlyStopping! Epoch 119
# Last: 106 	T-Loss: 0.574154 	T-Acc: 0.747556 	V-Loss: 0.576719 	V-Acc: 0.730000
# ## Test phase...
# Final test Loss: 0.599642
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.69431886 	Recall: 0.72177778 	Prec: 0.65431104
#
# ~~Result_C_1000_5~~
# EarlyStopping! Epoch 112
# Last: 99 	T-Loss: 0.566516 	T-Acc: 0.760185 	V-Loss: 0.564784 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.593098
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.70630746 	Recall: 0.73777778 	Prec: 0.66506410
#
# ~~Result_C_1000_6~~
# EarlyStopping! Epoch 97
# Last: 84 	T-Loss: 0.559208 	T-Acc: 0.766349 	V-Loss: 0.561336 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.589392
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.71415970 	Recall: 0.74844444 	Prec: 0.67198723
#
# ~~Result_C_1000_7~~
# EarlyStopping! Epoch 84
# Last: 71 	T-Loss: 0.555213 	T-Acc: 0.763611 	V-Loss: 0.560475 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.588226
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.70975690 	Recall: 0.76711111 	Prec: 0.66079632
#
# ~~Result_C_1000_8~~
# EarlyStopping! Epoch 83
# Last: 70 	T-Loss: 0.557088 	T-Acc: 0.765062 	V-Loss: 0.557743 	V-Acc: 0.730000
# ## Test phase...
# Final test Loss: 0.585786
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.71880213 	Recall: 0.76888889 	Prec: 0.67158385
#
# ~~Result_C_1000_9~~
# EarlyStopping! Epoch 65
# Last: 52 	T-Loss: 0.590686 	T-Acc: 0.739444 	V-Loss: 0.597433 	V-Acc: 0.730000
# ## Test phase...
# Final test Loss: 0.618909
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.69328921 	Recall: 0.74933333 	Prec: 0.64548239
#
# ~~Result_C_1000_10~~
# EarlyStopping! Epoch 75
# Last: 62 	T-Loss: 0.561913 	T-Acc: 0.766364 	V-Loss: 0.562523 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.591141
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.71749072 	Recall: 0.75555556 	Prec: 0.67406820
#
# ##### TOTAL_DATA 2500 #####
#
# ~~Result_A_2500~~
# EarlyStopping! Epoch 145
# Last: 132 	T-Loss: 0.512945 	T-Acc: 0.768889 	V-Loss: 0.517955 	V-Acc: 0.780000
# ## Test phase...
# Final test Loss: 0.602947
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.68052431 	Recall: 0.73155556 	Prec: 0.63454125
#
# ~~Result_B_2500~~
# EarlyStopping! Epoch 161
# Last: 148 	T-Loss: 0.595945 	T-Acc: 0.740889 	V-Loss: 0.599391 	V-Acc: 0.736000
# ## Test phase...
# Final test Loss: 0.656307
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.56279555 	Recall: 0.96177778 	Prec: 0.53804078
#
# ~~Result_C_2500_0.25~~
# EarlyStopping! Epoch 133
# Last: 120 	T-Loss: 0.533095 	T-Acc: 0.751866 	V-Loss: 0.519026 	V-Acc: 0.768000
# ## Test phase...
# Final test Loss: 0.602563
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.67640999 	Recall: 0.72977778 	Prec: 0.63008442
#
# ~~Result_C_2500_0.5~~
# EarlyStopping! Epoch 121
# Last: 108 	T-Loss: 0.551429 	T-Acc: 0.741037 	V-Loss: 0.523988 	V-Acc: 0.788000
# ## Test phase...
# Final test Loss: 0.606612
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.67558617 	Recall: 0.73066667 	Prec: 0.62892119
#
# ~~Result_C_2500_0.75~~
# EarlyStopping! Epoch 122
# Last: 109 	T-Loss: 0.547932 	T-Acc: 0.752158 	V-Loss: 0.515619 	V-Acc: 0.764000
# ## Test phase...
# Final test Loss: 0.596512
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.68464383 	Recall: 0.73866667 	Prec: 0.63775902
#
# ~~Result_C_2500_1~~
# EarlyStopping! Epoch 140
# Last: 127 	T-Loss: 0.540166 	T-Acc: 0.751333 	V-Loss: 0.489278 	V-Acc: 0.788000
# ## Test phase...
# Final test Loss: 0.581752
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.69369483 	Recall: 0.74400000 	Prec: 0.64733179
#
# ~~Result_C_2500_1.5~~
# EarlyStopping! Epoch 97
# Last: 84 	T-Loss: 0.556139 	T-Acc: 0.752356 	V-Loss: 0.507010 	V-Acc: 0.800000
# ## Test phase...
# Final test Loss: 0.588101
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.69369483 	Recall: 0.74400000 	Prec: 0.64733179
#
# ~~Result_C_2500_2~~
# EarlyStopping! Epoch 128
# Last: 115 	T-Loss: 0.519337 	T-Acc: 0.777778 	V-Loss: 0.460323 	V-Acc: 0.812000
# ## Test phase...
# Final test Loss: 0.547609
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.72332939 	Recall: 0.77333333 	Prec: 0.67599068
#
# ~~Result_C_2500_3~~
# EarlyStopping! Epoch 102
# Last: 89 	T-Loss: 0.517648 	T-Acc: 0.787667 	V-Loss: 0.470722 	V-Acc: 0.804000
# ## Test phase...
# Final test Loss: 0.551469
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.72704798 	Recall: 0.78400000 	Prec: 0.67741935
#
# ~~Result_C_2500_4~~
# EarlyStopping! Epoch 122
# Last: 109 	T-Loss: 0.499795 	T-Acc: 0.795378 	V-Loss: 0.444311 	V-Acc: 0.808000
# ## Test phase...
# Final test Loss: 0.529519
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.74927801 	Recall: 0.80622222 	Prec: 0.69876733
#
# ~~Result_C_2500_5~~
# EarlyStopping! Epoch 95
# Last: 82 	T-Loss: 0.486837 	T-Acc: 0.802074 	V-Loss: 0.428590 	V-Acc: 0.820000
# ## Test phase...
# Final test Loss: 0.517620
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.75791584 	Recall: 0.81155556 	Prec: 0.70830101
#
# ~~Result_C_2500_6~~
# EarlyStopping! Epoch 94
# Last: 81 	T-Loss: 0.498944 	T-Acc: 0.798476 	V-Loss: 0.443237 	V-Acc: 0.840000
# ## Test phase...
# Final test Loss: 0.531953
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.75092209 	Recall: 0.80622222 	Prec: 0.70092736
#
# ~~Result_C_2500_7~~
# EarlyStopping! Epoch 111
# Last: 98 	T-Loss: 0.453500 	T-Acc: 0.819889 	V-Loss: 0.402614 	V-Acc: 0.852000
# ## Test phase...
# Final test Loss: 0.486540
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77889978 	Recall: 0.83022222 	Prec: 0.72968750
#
# ~~Result_C_2500_8~~
# EarlyStopping! Epoch 99
# Last: 86 	T-Loss: 0.463575 	T-Acc: 0.815407 	V-Loss: 0.417031 	V-Acc: 0.844000
# ## Test phase...
# Final test Loss: 0.499268
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77397555 	Recall: 0.83022222 	Prec: 0.72291022
#
# ~~Result_C_2500_9~~
# EarlyStopping! Epoch 94
# Last: 81 	T-Loss: 0.476603 	T-Acc: 0.812622 	V-Loss: 0.430297 	V-Acc: 0.848000
# ## Test phase...
# Final test Loss: 0.513027
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.76739257 	Recall: 0.82577778 	Prec: 0.71571649
#
# ~~Result_C_2500_10~~
# EarlyStopping! Epoch 77
# Last: 64 	T-Loss: 0.467055 	T-Acc: 0.815434 	V-Loss: 0.426026 	V-Acc: 0.836000
# ## Test phase...
# Final test Loss: 0.503665
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77109918 	Recall: 0.83288889 	Prec: 0.71800766
#
# ##### TOTAL_DATA 5000 #####
#
# ~~Result_A_5000~~
# EarlyStopping! Epoch 138
# Last: 125 	T-Loss: 0.479146 	T-Acc: 0.786222 	V-Loss: 0.472023 	V-Acc: 0.788000
# ## Test phase...
# Final test Loss: 0.575610
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.70305407 	Recall: 0.78044444 	Prec: 0.64940828
#
# ~~Result_B_5000~~
# EarlyStopping! Epoch 142
# Last: 129 	T-Loss: 0.553179 	T-Acc: 0.772444 	V-Loss: 0.556546 	V-Acc: 0.734000
# ## Test phase...
# Final test Loss: 0.621559
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62902416 	Recall: 0.95288889 	Prec: 0.57295564
#
# ~~Result_C_5000_0.25~~
# EarlyStopping! Epoch 116
# Last: 103 	T-Loss: 0.505976 	T-Acc: 0.766756 	V-Loss: 0.473981 	V-Acc: 0.782000
# ## Test phase...
# Final test Loss: 0.575937
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.70174685 	Recall: 0.78488889 	Prec: 0.64688645
#
# ~~Result_C_5000_0.5~~
# EarlyStopping! Epoch 135
# Last: 122 	T-Loss: 0.501719 	T-Acc: 0.774222 	V-Loss: 0.458230 	V-Acc: 0.798000
# ## Test phase...
# Final test Loss: 0.553866
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.71903701 	Recall: 0.80444444 	Prec: 0.66203365
#
# ~~Result_C_5000_0.75~~
# EarlyStopping! Epoch 113
# Last: 100 	T-Loss: 0.514142 	T-Acc: 0.772444 	V-Loss: 0.460713 	V-Acc: 0.800000
# ## Test phase...
# Final test Loss: 0.559216
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.71570307 	Recall: 0.80355556 	Prec: 0.65841224
#
# ~~Result_C_5000_1~~
# EarlyStopping! Epoch 147
# Last: 134 	T-Loss: 0.494951 	T-Acc: 0.786667 	V-Loss: 0.435991 	V-Acc: 0.812000
# ## Test phase...
# Final test Loss: 0.530752
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.73513099 	Recall: 0.81955556 	Prec: 0.67694567
#
# ~~Result_C_5000_1.5~~
# EarlyStopping! Epoch 138
# Last: 125 	T-Loss: 0.472336 	T-Acc: 0.801600 	V-Loss: 0.415069 	V-Acc: 0.820000
# ## Test phase...
# Final test Loss: 0.505468
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.75536333 	Recall: 0.83644444 	Prec: 0.69652110
#
# ~~Result_C_5000_2~~
# EarlyStopping! Epoch 116
# Last: 103 	T-Loss: 0.473074 	T-Acc: 0.806370 	V-Loss: 0.413250 	V-Acc: 0.830000
# ## Test phase...
# Final test Loss: 0.505850
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.75692762 	Recall: 0.84622222 	Prec: 0.69539810
#
# ~~Result_C_5000_3~~
# EarlyStopping! Epoch 101
# Last: 88 	T-Loss: 0.469279 	T-Acc: 0.806111 	V-Loss: 0.417677 	V-Acc: 0.826000
# ## Test phase...
# Final test Loss: 0.500635
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.76450061 	Recall: 0.83288889 	Prec: 0.70931113
#
# ~~Result_C_5000_4~~
# EarlyStopping! Epoch 84
# Last: 71 	T-Loss: 0.460930 	T-Acc: 0.812889 	V-Loss: 0.403459 	V-Acc: 0.826000
# ## Test phase...
# Final test Loss: 0.494111
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77143591 	Recall: 0.85244444 	Prec: 0.71142433
#
# ~~Result_C_5000_5~~
# EarlyStopping! Epoch 90
# Last: 77 	T-Loss: 0.450170 	T-Acc: 0.817222 	V-Loss: 0.405386 	V-Acc: 0.838000
# ## Test phase...
# Final test Loss: 0.483895
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77926388 	Recall: 0.86044444 	Prec: 0.71863400
#
# ~~Result_C_5000_6~~
# EarlyStopping! Epoch 95
# Last: 82 	T-Loss: 0.422882 	T-Acc: 0.827905 	V-Loss: 0.382687 	V-Acc: 0.846000
# ## Test phase...
# Final test Loss: 0.457662
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79289138 	Recall: 0.86844444 	Prec: 0.73348348
#
# ~~Result_C_5000_7~~
# EarlyStopping! Epoch 76
# Last: 63 	T-Loss: 0.430417 	T-Acc: 0.824250 	V-Loss: 0.396107 	V-Acc: 0.832000
# ## Test phase...
# Final test Loss: 0.466738
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78991310 	Recall: 0.87911111 	Prec: 0.72560528
#
# ~~Result_C_5000_8~~
# EarlyStopping! Epoch 61
# Last: 48 	T-Loss: 0.449419 	T-Acc: 0.819531 	V-Loss: 0.412805 	V-Acc: 0.832000
# ## Test phase...
# Final test Loss: 0.485492
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77965138 	Recall: 0.86400000 	Prec: 0.71787297
#
# ~~Result_C_5000_9~~
# EarlyStopping! Epoch 78
# Last: 65 	T-Loss: 0.423876 	T-Acc: 0.829978 	V-Loss: 0.394303 	V-Acc: 0.838000
# ## Test phase...
# Final test Loss: 0.459907
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79042473 	Recall: 0.86488889 	Prec: 0.73157895
#
# ~~Result_C_5000_10~~
# EarlyStopping! Epoch 74
# Last: 61 	T-Loss: 0.412180 	T-Acc: 0.831051 	V-Loss: 0.379190 	V-Acc: 0.858000
# ## Test phase...
# Final test Loss: 0.446180
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79827086 	Recall: 0.86133333 	Prec: 0.74366846
#
# ##### TOTAL_DATA 7500 #####
#
# ~~Result_A_7500~~
# EarlyStopping! Epoch 151
# Last: 138 	T-Loss: 0.441987 	T-Acc: 0.802963 	V-Loss: 0.443693 	V-Acc: 0.805333
# ## Test phase...
# Final test Loss: 0.527373
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.74763260 	Recall: 0.80800000 	Prec: 0.69601838
#
# ~~Result_B_7500~~
# EarlyStopping! Epoch 112
# Last: 99 	T-Loss: 0.530108 	T-Acc: 0.788148 	V-Loss: 0.550445 	V-Acc: 0.736000
# ## Test phase...
# Final test Loss: 0.609042
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64246770 	Recall: 0.95111111 	Prec: 0.58120587
#
# ~~Result_C_7500_0.25~~
# EarlyStopping! Epoch 186
# Last: 173 	T-Loss: 0.444786 	T-Acc: 0.809196 	V-Loss: 0.419809 	V-Acc: 0.817333
# ## Test phase...
# Final test Loss: 0.496829
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77189009 	Recall: 0.84622222 	Prec: 0.71417854
#
# ~~Result_C_7500_0.5~~
# EarlyStopping! Epoch 134
# Last: 121 	T-Loss: 0.474494 	T-Acc: 0.789235 	V-Loss: 0.439935 	V-Acc: 0.808000
# ## Test phase...
# Final test Loss: 0.516715
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.74886746 	Recall: 0.80977778 	Prec: 0.69701607
#
# ~~Result_C_7500_0.75~~
# EarlyStopping! Epoch 97
# Last: 84 	T-Loss: 0.497950 	T-Acc: 0.779565 	V-Loss: 0.458331 	V-Acc: 0.801333
# ## Test phase...
# Final test Loss: 0.536868
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.73197375 	Recall: 0.79822222 	Prec: 0.67927383
#
# ~~Result_C_7500_1~~
# EarlyStopping! Epoch 166
# Last: 153 	T-Loss: 0.455199 	T-Acc: 0.808148 	V-Loss: 0.410991 	V-Acc: 0.825333
# ## Test phase...
# Final test Loss: 0.482542
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77806849 	Recall: 0.85244444 	Prec: 0.71996997
#
# ~~Result_C_7500_1.5~~
# EarlyStopping! Epoch 107
# Last: 94 	T-Loss: 0.466243 	T-Acc: 0.810133 	V-Loss: 0.420665 	V-Acc: 0.812000
# ## Test phase...
# Final test Loss: 0.495115
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.76778486 	Recall: 0.83911111 	Prec: 0.71137905
#
# ~~Result_C_7500_2~~
# EarlyStopping! Epoch 108
# Last: 95 	T-Loss: 0.463241 	T-Acc: 0.809333 	V-Loss: 0.422375 	V-Acc: 0.820000
# ## Test phase...
# Final test Loss: 0.490995
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.76902181 	Recall: 0.84000000 	Prec: 0.71266968
#
# ~~Result_C_7500_3~~
# EarlyStopping! Epoch 81
# Last: 68 	T-Loss: 0.447260 	T-Acc: 0.816778 	V-Loss: 0.416855 	V-Acc: 0.821333
# ## Test phase...
# Final test Loss: 0.473420
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78221476 	Recall: 0.84355556 	Prec: 0.72887865
#
# ~~Result_C_7500_4~~
# EarlyStopping! Epoch 102
# Last: 89 	T-Loss: 0.426080 	T-Acc: 0.825215 	V-Loss: 0.398343 	V-Acc: 0.822667
# ## Test phase...
# Final test Loss: 0.456928
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79124821 	Recall: 0.86577778 	Prec: 0.73233083
#
# ~~Result_C_7500_5~~
# EarlyStopping! Epoch 76
# Last: 63 	T-Loss: 0.430914 	T-Acc: 0.825481 	V-Loss: 0.403360 	V-Acc: 0.845333
# ## Test phase...
# Final test Loss: 0.462324
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78875027 	Recall: 0.86844444 	Prec: 0.72801788
#
# ~~Result_C_7500_6~~
# EarlyStopping! Epoch 73
# Last: 60 	T-Loss: 0.421439 	T-Acc: 0.827746 	V-Loss: 0.397598 	V-Acc: 0.841333
# ## Test phase...
# Final test Loss: 0.453693
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79536560 	Recall: 0.87022222 	Prec: 0.73609023
#
# ~~Result_C_7500_7~~
# EarlyStopping! Epoch 78
# Last: 65 	T-Loss: 0.412677 	T-Acc: 0.831278 	V-Loss: 0.400574 	V-Acc: 0.814667
# ## Test phase...
# Final test Loss: 0.444860
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79538905 	Recall: 0.85866667 	Prec: 0.74079755
#
# ~~Result_C_7500_8~~
# EarlyStopping! Epoch 78
# Last: 65 	T-Loss: 0.411281 	T-Acc: 0.831012 	V-Loss: 0.394244 	V-Acc: 0.838667
# ## Test phase...
# Final test Loss: 0.444445
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79620746 	Recall: 0.86488889 	Prec: 0.73936170
#
# ~~Result_C_7500_9~~
# EarlyStopping! Epoch 70
# Last: 57 	T-Loss: 0.408057 	T-Acc: 0.833719 	V-Loss: 0.400739 	V-Acc: 0.826667
# ## Test phase...
# Final test Loss: 0.442906
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79909343 	Recall: 0.86488889 	Prec: 0.74331551
#
# ~~Result_C_7500_10~~
# EarlyStopping! Epoch 72
# Last: 59 	T-Loss: 0.392648 	T-Acc: 0.836175 	V-Loss: 0.392156 	V-Acc: 0.837333
# ## Test phase...
# Final test Loss: 0.425752
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.80938193 	Recall: 0.86844444 	Prec: 0.75619195
#
# ##### TOTAL_DATA 12389 #####
#
# ~~Result_A_12389~~
# EarlyStopping! Epoch 128
# Last: 115 	T-Loss: 0.441212 	T-Acc: 0.806996 	V-Loss: 0.444416 	V-Acc: 0.816701
# ## Test phase...
# Final test Loss: 0.522825
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.74721384 	Recall: 0.81244444 	Prec: 0.69400152
#
# ~~Result_B_12389~~
# EarlyStopping! Epoch 120
# Last: 107 	T-Loss: 0.499218 	T-Acc: 0.809165 	V-Loss: 0.538597 	V-Acc: 0.731161
# ## Test phase...
# Final test Loss: 0.592096
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.65044943 	Recall: 0.96444444 	Prec: 0.58616964
#
# ~~Result_C_12389_0.25~~
# EarlyStopping! Epoch 145
# Last: 132 	T-Loss: 0.448672 	T-Acc: 0.806746 	V-Loss: 0.423307 	V-Acc: 0.818737
# ## Test phase...
# Final test Loss: 0.494038
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77066871 	Recall: 0.84177778 	Prec: 0.71417798
#
# ~~Result_C_12389_0.5~~
# EarlyStopping! Epoch 132
# Last: 119 	T-Loss: 0.446845 	T-Acc: 0.811229 	V-Loss: 0.412498 	V-Acc: 0.816701
# ## Test phase...
# Final test Loss: 0.477586
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78302887 	Recall: 0.85244444 	Prec: 0.72651515
#
# ~~Result_C_12389_0.75~~
# EarlyStopping! Epoch 133
# Last: 120 	T-Loss: 0.444189 	T-Acc: 0.812573 	V-Loss: 0.406285 	V-Acc: 0.826884
# ## Test phase...
# Final test Loss: 0.467788
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78755880 	Recall: 0.85688889 	Prec: 0.73085671
#
# ~~Result_C_12389_1~~
# EarlyStopping! Epoch 108
# Last: 95 	T-Loss: 0.447157 	T-Acc: 0.812559 	V-Loss: 0.410753 	V-Acc: 0.823829
# ## Test phase...
# Final test Loss: 0.470378
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78258647 	Recall: 0.85955556 	Prec: 0.72326103
#
# ~~Result_C_12389_1.5~~
# EarlyStopping! Epoch 130
# Last: 117 	T-Loss: 0.442093 	T-Acc: 0.817638 	V-Loss: 0.412323 	V-Acc: 0.822811
# ## Test phase...
# Final test Loss: 0.467169
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78837447 	Recall: 0.86044444 	Prec: 0.73056604
#
# ~~Result_C_12389_2~~
# EarlyStopping! Epoch 84
# Last: 71 	T-Loss: 0.434683 	T-Acc: 0.822547 	V-Loss: 0.412437 	V-Acc: 0.816701
# ## Test phase...
# Final test Loss: 0.463097
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78669923 	Recall: 0.86488889 	Prec: 0.72666169
#
# ~~Result_C_12389_3~~
# EarlyStopping! Epoch 81
# Last: 68 	T-Loss: 0.419283 	T-Acc: 0.828261 	V-Loss: 0.401339 	V-Acc: 0.826884
# ## Test phase...
# Final test Loss: 0.447277
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79741863 	Recall: 0.87377778 	Prec: 0.73743436
#
# ~~Result_C_12389_4~~
# EarlyStopping! Epoch 73
# Last: 60 	T-Loss: 0.413544 	T-Acc: 0.829681 	V-Loss: 0.407357 	V-Acc: 0.821792
# ## Test phase...
# Final test Loss: 0.439040
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.80279830 	Recall: 0.86400000 	Prec: 0.74884438
#
# ~~Result_C_12389_5~~
# EarlyStopping! Epoch 54
# Last: 41 	T-Loss: 0.421727 	T-Acc: 0.827994 	V-Loss: 0.412534 	V-Acc: 0.821792
# ## Test phase...
# Final test Loss: 0.454011
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79616766 	Recall: 0.87555556 	Prec: 0.73507463
#
# ~~Result_C_12389_6~~
# EarlyStopping! Epoch 75
# Last: 62 	T-Loss: 0.392003 	T-Acc: 0.836311 	V-Loss: 0.398429 	V-Acc: 0.829939
# ## Test phase...
# Final test Loss: 0.425612
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.80815121 	Recall: 0.87111111 	Prec: 0.75326672
#
# ~~Result_C_12389_7~~
# EarlyStopping! Epoch 53
# Last: 40 	T-Loss: 0.405374 	T-Acc: 0.832261 	V-Loss: 0.409424 	V-Acc: 0.828921
# ## Test phase...
# Final test Loss: 0.437470
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79908852 	Recall: 0.86844444 	Prec: 0.74183751
#
# ~~Result_C_12389_8~~
# EarlyStopping! Epoch 62
# Last: 49 	T-Loss: 0.391004 	T-Acc: 0.838405 	V-Loss: 0.400359 	V-Acc: 0.819756
# ## Test phase...
# Final test Loss: 0.424966
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.80815121 	Recall: 0.87377778 	Prec: 0.75210406
#
# ~~Result_C_12389_9~~
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/loss.py:498: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# EarlyStopping! Epoch 45
# Last: 32 	T-Loss: 0.401991 	T-Acc: 0.835023 	V-Loss: 0.411892 	V-Acc: 0.813646
# ## Test phase...
# Final test Loss: 0.435642
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.80238028 	Recall: 0.87288889 	Prec: 0.74450341
#
# ~~Result_C_12389_10~~
# EarlyStopping! Epoch 43
# Last: 30 	T-Loss: 0.399397 	T-Acc: 0.835783 	V-Loss: 0.415293 	V-Acc: 0.827902
# ## Test phase...
# Final test Loss: 0.432160
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.80485635 	Recall: 0.87200000 	Prec: 0.74828375
#
# ############################
# ### START RANDOM_SEED 5 ###
# ############################
#
# ##### TOTAL_DATA 500 #####
#
# ~~Result_A_500~~
# EarlyStopping! Epoch 14
# Last: 1 	T-Loss: 0.696380 	T-Acc: 0.513333 	V-Loss: 0.673274 	V-Acc: 0.620000
# ## Test phase...
# Final test Loss: 0.704791
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.31654474 	Recall: 1.00000000 	Prec: 0.46315356
#
# ~~Result_B_500~~
# EarlyStopping! Epoch 14
# Last: 1 	T-Loss: 0.700080 	T-Acc: 0.477778 	V-Loss: 0.674534 	V-Acc: 0.620000
# ## Test phase...
# Final test Loss: 0.703446
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.31654474 	Recall: 1.00000000 	Prec: 0.46315356
#
# ~~Result_C_500_0.25~~
# EarlyStopping! Epoch 16
# Last: 3 	T-Loss: 0.687868 	T-Acc: 0.525755 	V-Loss: 0.674385 	V-Acc: 0.640000
# ## Test phase...
# Final test Loss: 0.696815
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.31654474 	Recall: 1.00000000 	Prec: 0.46315356
#
# ~~Result_C_500_0.5~~
# EarlyStopping! Epoch 34
# Last: 21 	T-Loss: 0.683841 	T-Acc: 0.637037 	V-Loss: 0.675979 	V-Acc: 0.760000
# ## Test phase...
# Final test Loss: 0.688084
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61168910 	Recall: 0.64444444 	Prec: 0.57176656
#
# ~~Result_C_500_0.75~~
# EarlyStopping! Epoch 14
# Last: 1 	T-Loss: 0.697505 	T-Acc: 0.496193 	V-Loss: 0.674234 	V-Acc: 0.600000
# ## Test phase...
# Final test Loss: 0.701716
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.31654474 	Recall: 1.00000000 	Prec: 0.46315356
#
# ~~Result_C_500_1~~
# EarlyStopping! Epoch 18
# Last: 5 	T-Loss: 0.688681 	T-Acc: 0.537778 	V-Loss: 0.674689 	V-Acc: 0.680000
# ## Test phase...
# Final test Loss: 0.692053
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.43833236 	Recall: 0.94577778 	Prec: 0.48651120
#
# ~~Result_C_500_1.5~~
# EarlyStopping! Epoch 14
# Last: 1 	T-Loss: 0.695594 	T-Acc: 0.507556 	V-Loss: 0.679107 	V-Acc: 0.620000
# ## Test phase...
# Final test Loss: 0.698052
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.31654474 	Recall: 1.00000000 	Prec: 0.46315356
#
# ~~Result_C_500_2~~
# EarlyStopping! Epoch 48
# Last: 35 	T-Loss: 0.666770 	T-Acc: 0.664444 	V-Loss: 0.668610 	V-Acc: 0.640000
# ## Test phase...
# Final test Loss: 0.680796
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61342265 	Recall: 0.71288889 	Prec: 0.56638418
#
# ~~Result_C_500_3~~
# EarlyStopping! Epoch 24
# Last: 11 	T-Loss: 0.679599 	T-Acc: 0.614444 	V-Loss: 0.672400 	V-Acc: 0.680000
# ## Test phase...
# Final test Loss: 0.688881
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.54084783 	Recall: 0.86666667 	Prec: 0.51916933
#
# ~~Result_C_500_4~~
# EarlyStopping! Epoch 36
# Last: 23 	T-Loss: 0.664154 	T-Acc: 0.648444 	V-Loss: 0.662606 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.679795
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60646415 	Recall: 0.78044444 	Prec: 0.55746032
#
# ~~Result_C_500_5~~
# EarlyStopping! Epoch 54
# Last: 41 	T-Loss: 0.645247 	T-Acc: 0.684444 	V-Loss: 0.647067 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.661585
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64428450 	Recall: 0.70222222 	Prec: 0.59893859
#
# ~~Result_C_500_6~~
# EarlyStopping! Epoch 92
# Last: 79 	T-Loss: 0.621857 	T-Acc: 0.712381 	V-Loss: 0.628051 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.641894
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.66308737 	Recall: 0.69333333 	Prec: 0.62250599
#
# ~~Result_C_500_7~~
# EarlyStopping! Epoch 64
# Last: 51 	T-Loss: 0.650039 	T-Acc: 0.676944 	V-Loss: 0.653959 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.668421
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63890636 	Recall: 0.76533333 	Prec: 0.58571429
#
# ~~Result_C_500_8~~
# EarlyStopping! Epoch 97
# Last: 84 	T-Loss: 0.618296 	T-Acc: 0.713333 	V-Loss: 0.628501 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.639928
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.67380715 	Recall: 0.70577778 	Prec: 0.63266932
#
# ~~Result_C_500_9~~
# EarlyStopping! Epoch 62
# Last: 49 	T-Loss: 0.632293 	T-Acc: 0.694889 	V-Loss: 0.640325 	V-Acc: 0.740000
# ## Test phase...
# Final test Loss: 0.653184
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.65820748 	Recall: 0.72800000 	Prec: 0.60982874
#
# ~~Result_C_500_10~~
# EarlyStopping! Epoch 56
# Last: 43 	T-Loss: 0.624640 	T-Acc: 0.703030 	V-Loss: 0.627344 	V-Acc: 0.800000
# ## Test phase...
# Final test Loss: 0.646929
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.66235752 	Recall: 0.72888889 	Prec: 0.61423221
#
# ##### TOTAL_DATA 1000 #####
#
# ~~Result_A_1000~~
# EarlyStopping! Epoch 77
# Last: 64 	T-Loss: 0.636244 	T-Acc: 0.726667 	V-Loss: 0.652005 	V-Acc: 0.690000
# ## Test phase...
# Final test Loss: 0.668077
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63547237 	Recall: 0.66222222 	Prec: 0.59600000
#
# ~~Result_B_1000~~
# EarlyStopping! Epoch 14
# Last: 1 	T-Loss: 0.697291 	T-Acc: 0.495556 	V-Loss: 0.683239 	V-Acc: 0.590000
# ## Test phase...
# Final test Loss: 0.701054
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.31654474 	Recall: 1.00000000 	Prec: 0.46315356
#
# ~~Result_C_1000_0.25~~
# EarlyStopping! Epoch 74
# Last: 61 	T-Loss: 0.652154 	T-Acc: 0.712000 	V-Loss: 0.658832 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.672470
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63012444 	Recall: 0.65688889 	Prec: 0.59072742
#
# ~~Result_C_1000_0.5~~
# EarlyStopping! Epoch 92
# Last: 79 	T-Loss: 0.619073 	T-Acc: 0.715556 	V-Loss: 0.630930 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.651574
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64834197 	Recall: 0.68444444 	Prec: 0.60677699
#
# ~~Result_C_1000_0.75~~
# EarlyStopping! Epoch 82
# Last: 69 	T-Loss: 0.631751 	T-Acc: 0.695873 	V-Loss: 0.634876 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.655065
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64727301 	Recall: 0.66666667 	Prec: 0.60926076
#
# ~~Result_C_1000_1~~
# EarlyStopping! Epoch 91
# Last: 78 	T-Loss: 0.618228 	T-Acc: 0.708889 	V-Loss: 0.624098 	V-Acc: 0.710000
# ## Test phase...
# Final test Loss: 0.648542
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64932459 	Recall: 0.66844444 	Prec: 0.61138211
#
# ~~Result_C_1000_1.5~~
# EarlyStopping! Epoch 73
# Last: 60 	T-Loss: 0.655974 	T-Acc: 0.675556 	V-Loss: 0.658210 	V-Acc: 0.690000
# ## Test phase...
# Final test Loss: 0.674728
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61638770 	Recall: 0.73600000 	Prec: 0.56751199
#
# ~~Result_C_1000_2~~
# EarlyStopping! Epoch 89
# Last: 76 	T-Loss: 0.609809 	T-Acc: 0.706667 	V-Loss: 0.608735 	V-Acc: 0.710000
# ## Test phase...
# Final test Loss: 0.635044
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.66809082 	Recall: 0.68000000 	Prec: 0.63223140
#
# ~~Result_C_1000_3~~
# EarlyStopping! Epoch 120
# Last: 107 	T-Loss: 0.599373 	T-Acc: 0.723056 	V-Loss: 0.597438 	V-Acc: 0.710000
# ## Test phase...
# Final test Loss: 0.620825
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.67900986 	Recall: 0.70133333 	Prec: 0.64042208
#
# ~~Result_C_1000_4~~
# EarlyStopping! Epoch 113
# Last: 100 	T-Loss: 0.589057 	T-Acc: 0.737778 	V-Loss: 0.586736 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.612488
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.68351877 	Recall: 0.70488889 	Prec: 0.64524003
#
# ~~Result_C_1000_5~~
# EarlyStopping! Epoch 116
# Last: 103 	T-Loss: 0.554075 	T-Acc: 0.766111 	V-Loss: 0.556799 	V-Acc: 0.750000
# ## Test phase...
# Final test Loss: 0.577617
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.72228227 	Recall: 0.74844444 	Prec: 0.68288727
#
# ~~Result_C_1000_6~~
# EarlyStopping! Epoch 87
# Last: 74 	T-Loss: 0.567406 	T-Acc: 0.761270 	V-Loss: 0.567914 	V-Acc: 0.750000
# ## Test phase...
# Final test Loss: 0.594499
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.71006928 	Recall: 0.74666667 	Prec: 0.66719619
#
# ~~Result_C_1000_7~~
# EarlyStopping! Epoch 78
# Last: 65 	T-Loss: 0.575146 	T-Acc: 0.746667 	V-Loss: 0.564721 	V-Acc: 0.740000
# ## Test phase...
# Final test Loss: 0.602847
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.70268169 	Recall: 0.74133333 	Prec: 0.65928854
#
# ~~Result_C_1000_8~~
# EarlyStopping! Epoch 62
# Last: 49 	T-Loss: 0.585572 	T-Acc: 0.748642 	V-Loss: 0.588533 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.612174
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.70104220 	Recall: 0.74044444 	Prec: 0.65745856
#
# ~~Result_C_1000_9~~
# EarlyStopping! Epoch 83
# Last: 70 	T-Loss: 0.545013 	T-Acc: 0.777444 	V-Loss: 0.551785 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.575680
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.72783539 	Recall: 0.77333333 	Prec: 0.68181818
#
# ~~Result_C_1000_10~~
# EarlyStopping! Epoch 97
# Last: 84 	T-Loss: 0.532496 	T-Acc: 0.790101 	V-Loss: 0.541963 	V-Acc: 0.750000
# ## Test phase...
# Final test Loss: 0.561986
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.74589487 	Recall: 0.78488889 	Prec: 0.70190779
#
# ##### TOTAL_DATA 2500 #####
#
# ~~Result_A_2500~~
# EarlyStopping! Epoch 128
# Last: 115 	T-Loss: 0.520366 	T-Acc: 0.765778 	V-Loss: 0.529092 	V-Acc: 0.784000
# ## Test phase...
# Final test Loss: 0.608885
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.67681100 	Recall: 0.72444444 	Prec: 0.63178295
#
# ~~Result_B_2500~~
# EarlyStopping! Epoch 118
# Last: 105 	T-Loss: 0.612396 	T-Acc: 0.721333 	V-Loss: 0.614737 	V-Acc: 0.684000
# ## Test phase...
# Final test Loss: 0.667239
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.51567823 	Recall: 0.97955556 	Prec: 0.51932139
#
# ~~Result_C_2500_0.25~~
# EarlyStopping! Epoch 125
# Last: 112 	T-Loss: 0.532246 	T-Acc: 0.749378 	V-Loss: 0.516487 	V-Acc: 0.780000
# ## Test phase...
# Final test Loss: 0.601062
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.67681385 	Recall: 0.73600000 	Prec: 0.62917933
#
# ~~Result_C_2500_0.5~~
# EarlyStopping! Epoch 103
# Last: 90 	T-Loss: 0.548364 	T-Acc: 0.744000 	V-Loss: 0.521328 	V-Acc: 0.760000
# ## Test phase...
# Final test Loss: 0.604360
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.67557737 	Recall: 0.73511111 	Prec: 0.62794229
#
# ~~Result_C_2500_0.75~~
# EarlyStopping! Epoch 121
# Last: 108 	T-Loss: 0.546957 	T-Acc: 0.750127 	V-Loss: 0.509579 	V-Acc: 0.780000
# ## Test phase...
# Final test Loss: 0.593283
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.68833876 	Recall: 0.73688889 	Prec: 0.64263566
#
# ~~Result_C_2500_1~~
# EarlyStopping! Epoch 147
# Last: 134 	T-Loss: 0.529044 	T-Acc: 0.763333 	V-Loss: 0.479480 	V-Acc: 0.768000
# ## Test phase...
# Final test Loss: 0.567466
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.70521725 	Recall: 0.75466667 	Prec: 0.65865012
#
# ~~Result_C_2500_1.5~~
# EarlyStopping! Epoch 131
# Last: 118 	T-Loss: 0.535046 	T-Acc: 0.769244 	V-Loss: 0.484310 	V-Acc: 0.804000
# ## Test phase...
# Final test Loss: 0.568275
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.70768749 	Recall: 0.75733333 	Prec: 0.66097750
#
# ~~Result_C_2500_2~~
# EarlyStopping! Epoch 103
# Last: 90 	T-Loss: 0.533655 	T-Acc: 0.765185 	V-Loss: 0.477797 	V-Acc: 0.800000
# ## Test phase...
# Final test Loss: 0.562791
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.71058029 	Recall: 0.76800000 	Prec: 0.66156202
#
# ~~Result_C_2500_3~~
# EarlyStopping! Epoch 98
# Last: 85 	T-Loss: 0.535413 	T-Acc: 0.772222 	V-Loss: 0.478367 	V-Acc: 0.808000
# ## Test phase...
# Final test Loss: 0.566921
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.71675467 	Recall: 0.77155556 	Prec: 0.66820631
#
# ~~Result_C_2500_4~~
# EarlyStopping! Epoch 129
# Last: 116 	T-Loss: 0.489791 	T-Acc: 0.801244 	V-Loss: 0.434310 	V-Acc: 0.832000
# ## Test phase...
# Final test Loss: 0.519327
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.75956984 	Recall: 0.81688889 	Prec: 0.70855821
#
# ~~Result_C_2500_5~~
# EarlyStopping! Epoch 122
# Last: 109 	T-Loss: 0.480712 	T-Acc: 0.807407 	V-Loss: 0.428239 	V-Acc: 0.836000
# ## Test phase...
# Final test Loss: 0.508943
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.76203292 	Recall: 0.81600000 	Prec: 0.71217998
#
# ~~Result_C_2500_6~~
# EarlyStopping! Epoch 109
# Last: 96 	T-Loss: 0.464852 	T-Acc: 0.813714 	V-Loss: 0.418575 	V-Acc: 0.836000
# ## Test phase...
# Final test Loss: 0.497935
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77438170 	Recall: 0.82844444 	Prec: 0.72416472
#
# ~~Result_C_2500_7~~
# EarlyStopping! Epoch 79
# Last: 66 	T-Loss: 0.478051 	T-Acc: 0.811667 	V-Loss: 0.424873 	V-Acc: 0.824000
# ## Test phase...
# Final test Loss: 0.514592
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.76653008 	Recall: 0.84177778 	Prec: 0.70883234
#
# ~~Result_C_2500_8~~
# EarlyStopping! Epoch 96
# Last: 83 	T-Loss: 0.449314 	T-Acc: 0.821877 	V-Loss: 0.407261 	V-Acc: 0.808000
# ## Test phase...
# Final test Loss: 0.485020
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77850513 	Recall: 0.84533333 	Prec: 0.72319392
#
# ~~Result_C_2500_9~~
# EarlyStopping! Epoch 90
# Last: 77 	T-Loss: 0.453362 	T-Acc: 0.822222 	V-Loss: 0.401299 	V-Acc: 0.852000
# ## Test phase...
# Final test Loss: 0.489896
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77933212 	Recall: 0.83911111 	Prec: 0.72671286
#
# ~~Result_C_2500_10~~
# EarlyStopping! Epoch 64
# Last: 51 	T-Loss: 0.471840 	T-Acc: 0.811758 	V-Loss: 0.431612 	V-Acc: 0.824000
# ## Test phase...
# Final test Loss: 0.511413
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.76935859 	Recall: 0.85244444 	Prec: 0.70879527
#
# ##### TOTAL_DATA 5000 #####
#
# ~~Result_A_5000~~
# EarlyStopping! Epoch 168
# Last: 155 	T-Loss: 0.466026 	T-Acc: 0.794444 	V-Loss: 0.455531 	V-Acc: 0.806000
# ## Test phase...
# Final test Loss: 0.562575
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.71707472 	Recall: 0.79377778 	Prec: 0.66246291
#
# ~~Result_B_5000~~
# EarlyStopping! Epoch 153
# Last: 140 	T-Loss: 0.550297 	T-Acc: 0.778667 	V-Loss: 0.553453 	V-Acc: 0.752000
# ## Test phase...
# Final test Loss: 0.620413
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62243349 	Recall: 0.95822222 	Prec: 0.56916579
#
# ~~Result_C_5000_0.25~~
# EarlyStopping! Epoch 155
# Last: 142 	T-Loss: 0.482651 	T-Acc: 0.784889 	V-Loss: 0.448574 	V-Acc: 0.806000
# ## Test phase...
# Final test Loss: 0.549500
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.72365552 	Recall: 0.80177778 	Prec: 0.66814815
#
# ~~Result_C_5000_0.5~~
# EarlyStopping! Epoch 108
# Last: 95 	T-Loss: 0.519164 	T-Acc: 0.759704 	V-Loss: 0.473815 	V-Acc: 0.780000
# ## Test phase...
# Final test Loss: 0.573980
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.70008643 	Recall: 0.78400000 	Prec: 0.64520849
#
# ~~Result_C_5000_0.75~~
# EarlyStopping! Epoch 123
# Last: 110 	T-Loss: 0.493755 	T-Acc: 0.781206 	V-Loss: 0.436923 	V-Acc: 0.828000
# ## Test phase...
# Final test Loss: 0.537699
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# ...
#
# ~~Result_C_2500_10~~
# EarlyStopping! Epoch 105
# Last: 92 	T-Loss: 0.471417 	T-Acc: 0.814101 	V-Loss: 0.426648 	V-Acc: 0.832000
# ## Test phase...
# Final test Loss: 0.508087
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77068613 	Recall: 0.83466667 	Prec: 0.71679389
#
# ##### TOTAL_DATA 5000 #####
#
# ~~Result_A_5000~~
# EarlyStopping! Epoch 147
# Last: 134 	T-Loss: 0.465083 	T-Acc: 0.795556 	V-Loss: 0.455176 	V-Acc: 0.806000
# ## Test phase...
# Final test Loss: 0.564089
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.71337250 	Recall: 0.78933333 	Prec: 0.65924276
#
# ~~Result_B_5000~~
# EarlyStopping! Epoch 123
# Last: 110 	T-Loss: 0.576414 	T-Acc: 0.756444 	V-Loss: 0.571199 	V-Acc: 0.728000
# ## Test phase...
# Final test Loss: 0.634210
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61078264 	Recall: 0.95911111 	Prec: 0.56256517
#
# ~~Result_C_5000_0.25~~
# EarlyStopping! Epoch 172
# Last: 159 	T-Loss: 0.490031 	T-Acc: 0.778667 	V-Loss: 0.454651 	V-Acc: 0.802000
# ## Test phase...
# Final test Loss: 0.559659
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.71824748 	Recall: 0.80088889 	Prec: 0.66201323
#
# ~~Result_C_5000_0.5~~
# EarlyStopping! Epoch 166
# Last: 153 	T-Loss: 0.476663 	T-Acc: 0.788000 	V-Loss: 0.428944 	V-Acc: 0.814000
# ## Test phase...
# Final test Loss: 0.522930
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.74174144 	Recall: 0.82488889 	Prec: 0.68335788
#
# ~~Result_C_5000_0.75~~
# EarlyStopping! Epoch 167
# Last: 154 	T-Loss: 0.491991 	T-Acc: 0.785016 	V-Loss: 0.436414 	V-Acc: 0.806000
# ## Test phase...
# Final test Loss: 0.532892
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.73303237 	Recall: 0.82044444 	Prec: 0.67421476
#
# ~~Result_C_5000_1~~
# EarlyStopping! Epoch 125
# Last: 112 	T-Loss: 0.516725 	T-Acc: 0.776000 	V-Loss: 0.460726 	V-Acc: 0.800000
# ## Test phase...
# Final test Loss: 0.557774
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.72021527 	Recall: 0.80977778 	Prec: 0.66206395
#
# ~~Result_C_5000_1.5~~
# EarlyStopping! Epoch 130
# Last: 117 	T-Loss: 0.493882 	T-Acc: 0.792622 	V-Loss: 0.435031 	V-Acc: 0.816000
# ## Test phase...
# Final test Loss: 0.529352
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.73758119 	Recall: 0.82400000 	Prec: 0.67862372
#
# ~~Result_C_5000_2~~
# EarlyStopping! Epoch 99
# Last: 86 	T-Loss: 0.488942 	T-Acc: 0.794741 	V-Loss: 0.430873 	V-Acc: 0.806000
# ## Test phase...
# Final test Loss: 0.519701
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.74663349 	Recall: 0.83466667 	Prec: 0.68640351
#
# ~~Result_C_5000_3~~
# EarlyStopping! Epoch 101
# Last: 88 	T-Loss: 0.482519 	T-Acc: 0.799889 	V-Loss: 0.430956 	V-Acc: 0.812000
# ## Test phase...
# Final test Loss: 0.514810
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.75456161 	Recall: 0.83288889 	Prec: 0.69665428
#
# ~~Result_C_5000_4~~
# EarlyStopping! Epoch 87
# Last: 74 	T-Loss: 0.454783 	T-Acc: 0.817556 	V-Loss: 0.407605 	V-Acc: 0.824000
# ## Test phase...
# Final test Loss: 0.490157
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77222991 	Recall: 0.85688889 	Prec: 0.71091445
#
# ~~Result_C_5000_5~~
# EarlyStopping! Epoch 80
# Last: 67 	T-Loss: 0.446460 	T-Acc: 0.820407 	V-Loss: 0.393320 	V-Acc: 0.842000
# ## Test phase...
# Final test Loss: 0.482909
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77965138 	Recall: 0.86400000 	Prec: 0.71787297
#
# ~~Result_C_5000_6~~
# EarlyStopping! Epoch 88
# Last: 75 	T-Loss: 0.441112 	T-Acc: 0.820159 	V-Loss: 0.394368 	V-Acc: 0.854000
# ## Test phase...
# Final test Loss: 0.475553
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78297943 	Recall: 0.86311111 	Prec: 0.72247024
#
# ~~Result_C_5000_7~~
# EarlyStopping! Epoch 89
# Last: 76 	T-Loss: 0.432858 	T-Acc: 0.825694 	V-Loss: 0.390965 	V-Acc: 0.838000
# ## Test phase...
# Final test Loss: 0.469668
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78583298 	Recall: 0.87022222 	Prec: 0.72357724
#
# ~~Result_C_5000_8~~
# EarlyStopping! Epoch 87
# Last: 74 	T-Loss: 0.427559 	T-Acc: 0.829259 	V-Loss: 0.395722 	V-Acc: 0.830000
# ## Test phase...
# Final test Loss: 0.462351
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78876975 	Recall: 0.86488889 	Prec: 0.72938531
#
# ~~Result_C_5000_9~~
# EarlyStopping! Epoch 74
# Last: 61 	T-Loss: 0.414661 	T-Acc: 0.831756 	V-Loss: 0.373832 	V-Acc: 0.862000
# ## Test phase...
# Final test Loss: 0.446471
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79619862 	Recall: 0.85066667 	Prec: 0.74532710
#
# ~~Result_C_5000_10~~
# EarlyStopping! Epoch 83
# Last: 70 	T-Loss: 0.404103 	T-Acc: 0.834263 	V-Loss: 0.377721 	V-Acc: 0.832000
# ## Test phase...
# Final test Loss: 0.438789
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79991763 	Recall: 0.86311111 	Prec: 0.74520338
#
# ##### TOTAL_DATA 7500 #####
#
# ~~Result_A_7500~~
# EarlyStopping! Epoch 124
# Last: 111 	T-Loss: 0.462921 	T-Acc: 0.795852 	V-Loss: 0.465880 	V-Acc: 0.798667
# ## Test phase...
# Final test Loss: 0.553505
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.72415281 	Recall: 0.78933333 	Prec: 0.67221802
#
# ~~Result_B_7500~~
# EarlyStopping! Epoch 109
# Last: 96 	T-Loss: 0.531823 	T-Acc: 0.788444 	V-Loss: 0.546521 	V-Acc: 0.768000
# ## Test phase...
# Final test Loss: 0.603985
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.66004920 	Recall: 0.94577778 	Prec: 0.59275766
#
# ~~Result_C_7500_0.25~~
# EarlyStopping! Epoch 101
# Last: 88 	T-Loss: 0.486052 	T-Acc: 0.779924 	V-Loss: 0.462442 	V-Acc: 0.796000
# ## Test phase...
# Final test Loss: 0.547414
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.72745871 	Recall: 0.78755556 	Prec: 0.67685256
#
# ~~Result_C_7500_0.5~~
# EarlyStopping! Epoch 137
# Last: 124 	T-Loss: 0.468526 	T-Acc: 0.799605 	V-Loss: 0.430545 	V-Acc: 0.814667
# ## Test phase...
# Final test Loss: 0.506399
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.75586661 	Recall: 0.81600000 	Prec: 0.70398773
#
# ~~Result_C_7500_0.75~~
# EarlyStopping! Epoch 102
# Last: 89 	T-Loss: 0.488261 	T-Acc: 0.785660 	V-Loss: 0.444592 	V-Acc: 0.797333
# ## Test phase...
# Final test Loss: 0.522639
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.74433767 	Recall: 0.80622222 	Prec: 0.69236641
#
# ~~Result_C_7500_1~~
# EarlyStopping! Epoch 115
# Last: 102 	T-Loss: 0.480895 	T-Acc: 0.793630 	V-Loss: 0.434588 	V-Acc: 0.806667
# ## Test phase...
# Final test Loss: 0.514305
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.75008598 	Recall: 0.81866667 	Prec: 0.69561934
#
# ~~Result_C_7500_1.5~~
# EarlyStopping! Epoch 114
# Last: 101 	T-Loss: 0.456341 	T-Acc: 0.811319 	V-Loss: 0.412581 	V-Acc: 0.838667
# ## Test phase...
# Final test Loss: 0.480985
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77397125 	Recall: 0.84266667 	Prec: 0.71818182
#
# ~~Result_C_7500_2~~
# EarlyStopping! Epoch 109
# Last: 96 	T-Loss: 0.446390 	T-Acc: 0.814321 	V-Loss: 0.408207 	V-Acc: 0.824000
# ## Test phase...
# Final test Loss: 0.472031
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78384980 	Recall: 0.85422222 	Prec: 0.72692890
#
# ~~Result_C_7500_3~~
# EarlyStopping! Epoch 95
# Last: 82 	T-Loss: 0.447753 	T-Acc: 0.818185 	V-Loss: 0.407847 	V-Acc: 0.833333
# ## Test phase...
# Final test Loss: 0.478579
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77681112 	Recall: 0.85511111 	Prec: 0.71737509
#
# ~~Result_C_7500_4~~
# EarlyStopping! Epoch 95
# Last: 82 	T-Loss: 0.432380 	T-Acc: 0.822400 	V-Loss: 0.402608 	V-Acc: 0.845333
# ## Test phase...
# Final test Loss: 0.462402
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79001823 	Recall: 0.86311111 	Prec: 0.73172570
#
# ~~Result_C_7500_5~~
# EarlyStopping! Epoch 98
# Last: 85 	T-Loss: 0.412157 	T-Acc: 0.832198 	V-Loss: 0.392778 	V-Acc: 0.826667
# ## Test phase...
# Final test Loss: 0.443958
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79990271 	Recall: 0.87288889 	Prec: 0.74113208
#
# ~~Result_C_7500_6~~
# EarlyStopping! Epoch 88
# Last: 75 	T-Loss: 0.425685 	T-Acc: 0.826074 	V-Loss: 0.399521 	V-Acc: 0.844000
# ## Test phase...
# Final test Loss: 0.456918
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79126067 	Recall: 0.86222222 	Prec: 0.73373676
#
# ~~Result_C_7500_7~~
# EarlyStopping! Epoch 71
# Last: 58 	T-Loss: 0.430300 	T-Acc: 0.825370 	V-Loss: 0.406825 	V-Acc: 0.833333
# ## Test phase...
# Final test Loss: 0.461905
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78712692 	Recall: 0.86222222 	Prec: 0.72822823
#
# ~~Result_C_7500_8~~
# EarlyStopping! Epoch 59
# Last: 46 	T-Loss: 0.417441 	T-Acc: 0.827802 	V-Loss: 0.401328 	V-Acc: 0.829333
# ## Test phase...
# Final test Loss: 0.451028
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79412463 	Recall: 0.87022222 	Prec: 0.73443361
#
# ~~Result_C_7500_9~~
# EarlyStopping! Epoch 55
# Last: 42 	T-Loss: 0.419281 	T-Acc: 0.828830 	V-Loss: 0.398987 	V-Acc: 0.845333
# ## Test phase...
# Final test Loss: 0.448916
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79497315 	Recall: 0.85333333 	Prec: 0.74245940
#
# ~~Result_C_7500_10~~
# EarlyStopping! Epoch 69
# Last: 56 	T-Loss: 0.396134 	T-Acc: 0.836350 	V-Loss: 0.392194 	V-Acc: 0.836000
# ## Test phase...
# Final test Loss: 0.429635
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.80938542 	Recall: 0.87111111 	Prec: 0.75500770
#
# ##### TOTAL_DATA 12389 #####
#
# ~~Result_A_12389~~
# EarlyStopping! Epoch 127
# Last: 114 	T-Loss: 0.436127 	T-Acc: 0.812316 	V-Loss: 0.440876 	V-Acc: 0.814664
# ## Test phase...
# Final test Loss: 0.517556
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.75215630 	Recall: 0.80711111 	Prec: 0.70224285
#
# ~~Result_B_12389~~
# EarlyStopping! Epoch 91
# Last: 78 	T-Loss: 0.509627 	T-Acc: 0.803964 	V-Loss: 0.538330 	V-Acc: 0.744399
# ## Test phase...
# Final test Loss: 0.590379
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.66105168 	Recall: 0.95288889 	Prec: 0.59324848
#
# ~~Result_C_12389_0.25~~
# EarlyStopping! Epoch 163
# Last: 150 	T-Loss: 0.441147 	T-Acc: 0.807692 	V-Loss: 0.415157 	V-Acc: 0.820774
# ## Test phase...
# Final test Loss: 0.481489
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78054671 	Recall: 0.85333333 	Prec: 0.72289157
#
# ~~Result_C_12389_0.5~~
# EarlyStopping! Epoch 129
# Last: 116 	T-Loss: 0.451143 	T-Acc: 0.812270 	V-Loss: 0.417032 	V-Acc: 0.825866
# ## Test phase...
# Final test Loss: 0.481464
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.78097355 	Recall: 0.84888889 	Prec: 0.72513288
#
# ~~Result_C_12389_0.75~~
# EarlyStopping! Epoch 122
# Last: 109 	T-Loss: 0.452016 	T-Acc: 0.809316 	V-Loss: 0.415281 	V-Acc: 0.820774
# ## Test phase...
# Final test Loss: 0.479759
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77722007 	Recall: 0.85600000 	Prec: 0.71758569
#
# ~~Result_C_12389_1~~
# EarlyStopping! Epoch 126
# Last: 113 	T-Loss: 0.439657 	T-Acc: 0.814361 	V-Loss: 0.398629 	V-Acc: 0.830957
# ## Test phase...
# Final test Loss: 0.460564
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79456065 	Recall: 0.86311111 	Prec: 0.73784195
#
# ~~Result_C_12389_1.5~~
# EarlyStopping! Epoch 80
# Last: 67 	T-Loss: 0.453559 	T-Acc: 0.811534 	V-Loss: 0.415700 	V-Acc: 0.822811
# ## Test phase...
# Final test Loss: 0.477061
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77973938 	Recall: 0.84711111 	Prec: 0.72416413
#
# ~~Result_C_12389_2~~
# EarlyStopping! Epoch 108
# Last: 95 	T-Loss: 0.448038 	T-Acc: 0.818339 	V-Loss: 0.418551 	V-Acc: 0.822811
# ## Test phase...
# Final test Loss: 0.475506
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.77845256 	Recall: 0.85777778 	Prec: 0.71854058
#
# ~~Result_C_12389_3~~
# EarlyStopping! Epoch 85
# Last: 72 	T-Loss: 0.424240 	T-Acc: 0.825919 	V-Loss: 0.406475 	V-Acc: 0.825866
# ## Test phase...
# Final test Loss: 0.450700
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79414138 	Recall: 0.86577778 	Prec: 0.73620559
#
# ~~Result_C_12389_4~~
# EarlyStopping! Epoch 98
# Last: 85 	T-Loss: 0.409243 	T-Acc: 0.831215 	V-Loss: 0.397972 	V-Acc: 0.828921
# ## Test phase...
# Final test Loss: 0.437861
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.80197277 	Recall: 0.87022222 	Prec: 0.74505327
#
# ~~Result_C_12389_5~~
# EarlyStopping! Epoch 85
# Last: 72 	T-Loss: 0.396556 	T-Acc: 0.835767 	V-Loss: 0.396270 	V-Acc: 0.825866
# ## Test phase...
# Final test Loss: 0.430256
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.80691433 	Recall: 0.87466667 	Prec: 0.75000000
#
# ~~Result_C_12389_6~~
# EarlyStopping! Epoch 62
# Last: 49 	T-Loss: 0.406467 	T-Acc: 0.832165 	V-Loss: 0.410370 	V-Acc: 0.829939
# ## Test phase...
# Final test Loss: 0.438036
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.79950583 	Recall: 0.86400000 	Prec: 0.74425727
#
# ~~Result_C_12389_7~~
# EarlyStopping! Epoch 86
# Last: 73 	T-Loss: 0.392233 	T-Acc: 0.839075 	V-Loss: 0.400453 	V-Acc: 0.832994
# ## Test phase...
# Final test Loss: 0.426922
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.80485635 	Recall: 0.87200000 	Prec: 0.74828375
#
# ~~Result_C_12389_8~~
# EarlyStopping! Epoch 42
# Last: 29 	T-Loss: 0.415667 	T-Acc: 0.831111 	V-Loss: 0.411683 	V-Acc: 0.814664
# ## Test phase...
# Final test Loss: 0.446355
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.80030647 	Recall: 0.87555556 	Prec: 0.74060150
#
# ~~Result_C_12389_9~~
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/loss.py:498: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# EarlyStopping! Epoch 68
# Last: 55 	T-Loss: 0.380717 	T-Acc: 0.840509 	V-Loss: 0.400525 	V-Acc: 0.812627
# ## Test phase...
# Final test Loss: 0.413873
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.81103322 	Recall: 0.87466667 	Prec: 0.75576037
#
# ~~Result_C_12389_10~~
# EarlyStopping! Epoch 53
# Last: 40 	T-Loss: 0.390967 	T-Acc: 0.838135 	V-Loss: 0.412075 	V-Acc: 0.813646
# ## Test phase...
# Final test Loss: 0.427073
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.80401993 	Recall: 0.87733333 	Prec: 0.74490566

# %% [markdown]
# ## Save

# %%
final_result = pd.DataFrame(result_list_final) 
final_result = final_result.sort_values(by=['total_data', 'foreign_mult'])
final_result.to_csv('final_{}_{}_{}_result_combined.csv'.format(INDO_DATA_NAME,
                                                               FOREIGN_DATA_NAME,
                                                               MODEL_NAME),
                        index=False)

# %%
print(final_result.shape)
final_result.head()
# Out:
# (288, 8)
#     type  total_data  seed  foreign_mult  total_foreign_data        f1  \
# 1      B         500     4          -1.0                 500  0.464093
# 97     B         500     5          -1.0                 500  0.316545
# 193    B         500     6          -1.0                 500  0.350663
# 0      A         500     4           0.0                   0  0.516786
# 96     A         500     5           0.0                   0  0.316545
#
#        recall  precision
# 1    0.667556   0.454600
# 97   1.000000   0.463154
# 193  0.002667   0.250000
# 0    0.820444   0.502176
# 96   1.000000   0.463154
