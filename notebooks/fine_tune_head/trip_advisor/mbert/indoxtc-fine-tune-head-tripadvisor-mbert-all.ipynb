# %% [markdown]
# # IndoXTC - Fine-tune Head Toxic [mBERT] [ALL]
# Exploring Indonesian hate speech/abusive & sentiment text classification using multilingual language model.
#
# This kernel is a part of my undergraduate final year project.
# Checkout the full github repository:
# https://github.com/ilhamfp/indonesian-text-classification-multilingual

# %%
#############################
# Experiment configurations #
#############################

INDO_DATA_NAME = 'trip_advisor'
DATA_PATH_INDO = '../input/indoxtc-extracting-tripadvisor-features-mbert'

FOREIGN_DATA_NAME = 'yelp'
DATA_PATH_FOREIGN = '../input/indoxtc-combining-yelp-features-mbert'

MODEL_NAME = 'mBERT'

EXPERIMENT_TYPE_LIST = ['A', 'B', 'C'] # A / B / C
TOTAL_DATA_LIST = [500, 1000, 2500, 5000, 7500, 12389]
FOREIGN_LANG_DATA_MULT_LIST = [0.25, 0.5, 0.75, 1, 1.5, 2, 3, 4, 5, 6, 7, 8, 9, 10]
RANDOM_SEED_LIST = [4,5,6]
VALIDATION_DATA = 0.1

# %%
import os
import numpy as np
import pandas as pd
from load_data import load_experiment_features, set_random_seed_data
from model_head import set_seed, train, test, evaluate
# Out:
# CUDA is not available.  Training on CPU ...

# %% [markdown]
# ## Experiment

# %%
result_list_final = []
for RANDOM_SEED in RANDOM_SEED_LIST:
    print("\n############################")
    print("### START RANDOM_SEED {} ###".format(RANDOM_SEED))
    print("############################")
    result_list = []
    for TOTAL_DATA in TOTAL_DATA_LIST:
        print("\n##### TOTAL_DATA {} #####".format(TOTAL_DATA))

        for EXPERIMENT_TYPE in EXPERIMENT_TYPE_LIST:
            for FOREIGN_LANG_DATA_MULT in FOREIGN_LANG_DATA_MULT_LIST:
                set_seed(seed=RANDOM_SEED)
                set_random_seed_data(seed=RANDOM_SEED)
                if EXPERIMENT_TYPE != 'C':
                    print('\n~~Result_{}_{}~~'.format(EXPERIMENT_TYPE,
                                                       TOTAL_DATA))
                else:
                    print('\n~~Result_{}_{}_{}~~'.format(EXPERIMENT_TYPE,
                                                   TOTAL_DATA,
                                                   FOREIGN_LANG_DATA_MULT))

                train_loader, valid_loader, test_loader = load_experiment_features(DATA_PATH_INDO,
                                                                                   DATA_PATH_FOREIGN,
                                                                                   tipe=EXPERIMENT_TYPE, 
                                                                                   total_data=TOTAL_DATA, 
                                                                                   foreign_mult=FOREIGN_LANG_DATA_MULT,
                                                                                   valid_size=VALIDATION_DATA)

                train(train_loader, valid_loader, learning_rate=0.0001, input_dim=768)
                print("## Test phase...")
                y_true, y_pred_proba = test(test_loader, input_dim=768)
                max_f1, max_recall, max_precision, max_threshold = evaluate(y_true, 
                                                                            y_pred_proba,
                                                                            threshold=0.5)

                result = pd.DataFrame({
                    'y_true': y_true,
                    'y_pred_proba': y_pred_proba
                })
                
                OUTPUT_FOREIGN_LANG_DATA_MULT = FOREIGN_LANG_DATA_MULT
                if EXPERIMENT_TYPE == 'A':
                    OUTPUT_FOREIGN_LANG_DATA_MULT = 0
                elif EXPERIMENT_TYPE == 'B':
                    OUTPUT_FOREIGN_LANG_DATA_MULT = -1
                
                OUTPUT_TOTAL_FOREIGN_DATA = int(TOTAL_DATA*FOREIGN_LANG_DATA_MULT)
                if EXPERIMENT_TYPE == 'A':
                    OUTPUT_TOTAL_FOREIGN_DATA = 0
                elif EXPERIMENT_TYPE == 'B':
                    OUTPUT_TOTAL_FOREIGN_DATA = TOTAL_DATA

                result_list.append({
                    'type':EXPERIMENT_TYPE,
                    'total_data':TOTAL_DATA, 
                    'seed':RANDOM_SEED,
                    'foreign_mult':OUTPUT_FOREIGN_LANG_DATA_MULT,
                    'total_foreign_data':OUTPUT_TOTAL_FOREIGN_DATA,
                    'f1':max_f1,
                    'recall':max_recall,
                    'precision':max_precision
                })

                os.remove("model.pt")

                if EXPERIMENT_TYPE != 'C':
                    break
                    
    final_result = pd.DataFrame(result_list) 
    final_result = final_result.sort_values(by=['total_data', 'foreign_mult'])
    final_result.to_csv('final_{}_{}_{}_result_combined_seed_{}.csv'.format(INDO_DATA_NAME,
                                                                           FOREIGN_DATA_NAME,
                                                                           MODEL_NAME,
                                                                           RANDOM_SEED),
                        index=False)
    
    result_list_final.extend(result_list)
# Out:
# ############################
# ### START RANDOM_SEED 4 ###
# ############################
#
# ##### TOTAL_DATA 500 #####
#
# ~~Result_A_500~~
# EarlyStopping! Epoch 20
# Last: 7 	T-Loss: 0.673595 	T-Acc: 0.593333 	V-Loss: 0.703982 	V-Acc: 0.500000
# ## Test phase...
# Final test Loss: 0.709043
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48358873 	Recall: 0.60177778 	Prec: 0.45836154
#
# ~~Result_B_500~~
# EarlyStopping! Epoch 32
# Last: 19 	T-Loss: 0.684471 	T-Acc: 0.566667 	V-Loss: 0.698719 	V-Acc: 0.480000
# ## Test phase...
# Final test Loss: 0.698008
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48426899 	Recall: 0.59822222 	Prec: 0.45844687
#
# ~~Result_C_500_0.25~~
# EarlyStopping! Epoch 46
# Last: 33 	T-Loss: 0.666279 	T-Acc: 0.600355 	V-Loss: 0.697509 	V-Acc: 0.480000
# ## Test phase...
# Final test Loss: 0.708653
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.49093091 	Recall: 0.59733333 	Prec: 0.46312888
#
# ~~Result_C_500_0.5~~
# EarlyStopping! Epoch 15
# Last: 2 	T-Loss: 0.678755 	T-Acc: 0.579259 	V-Loss: 0.710764 	V-Acc: 0.500000
# ## Test phase...
# Final test Loss: 0.703206
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.49028908 	Recall: 0.56177778 	Prec: 0.45930233
#
# ~~Result_C_500_0.75~~
# EarlyStopping! Epoch 36
# Last: 23 	T-Loss: 0.671375 	T-Acc: 0.587563 	V-Loss: 0.705732 	V-Acc: 0.480000
# ## Test phase...
# Final test Loss: 0.703874
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.49069177 	Recall: 0.59377778 	Prec: 0.46260388
#
# ~~Result_C_500_1~~
# EarlyStopping! Epoch 56
# Last: 43 	T-Loss: 0.672953 	T-Acc: 0.590000 	V-Loss: 0.693076 	V-Acc: 0.480000
# ## Test phase...
# Final test Loss: 0.701583
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48928862 	Recall: 0.60266667 	Prec: 0.46248295
#
# ~~Result_C_500_1.5~~
# EarlyStopping! Epoch 33
# Last: 20 	T-Loss: 0.674386 	T-Acc: 0.578667 	V-Loss: 0.689796 	V-Acc: 0.480000
# ## Test phase...
# Final test Loss: 0.700570
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48046785 	Recall: 0.63377778 	Prec: 0.46000000
#
# ~~Result_C_500_2~~
# EarlyStopping! Epoch 20
# Last: 7 	T-Loss: 0.677811 	T-Acc: 0.575556 	V-Loss: 0.705017 	V-Acc: 0.480000
# ## Test phase...
# Final test Loss: 0.705444
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48669277 	Recall: 0.60177778 	Prec: 0.46054422
#
# ~~Result_C_500_3~~
# EarlyStopping! Epoch 37
# Last: 24 	T-Loss: 0.667654 	T-Acc: 0.593889 	V-Loss: 0.687526 	V-Acc: 0.480000
# ## Test phase...
# Final test Loss: 0.700975
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47396586 	Recall: 0.64266667 	Prec: 0.45701643
#
# ~~Result_C_500_4~~
# EarlyStopping! Epoch 28
# Last: 15 	T-Loss: 0.666449 	T-Acc: 0.604444 	V-Loss: 0.682152 	V-Acc: 0.560000
# ## Test phase...
# Final test Loss: 0.697990
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46700917 	Recall: 0.65333333 	Prec: 0.45426452
#
# ~~Result_C_500_5~~
# EarlyStopping! Epoch 28
# Last: 15 	T-Loss: 0.671857 	T-Acc: 0.595556 	V-Loss: 0.686245 	V-Acc: 0.500000
# ## Test phase...
# Final test Loss: 0.696790
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46913779 	Recall: 0.65155556 	Prec: 0.45527950
#
# ~~Result_C_500_6~~
# EarlyStopping! Epoch 30
# Last: 17 	T-Loss: 0.662999 	T-Acc: 0.593651 	V-Loss: 0.676209 	V-Acc: 0.560000
# ## Test phase...
# Final test Loss: 0.695714
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46507223 	Recall: 0.67733333 	Prec: 0.45656081
#
# ~~Result_C_500_7~~
# EarlyStopping! Epoch 25
# Last: 12 	T-Loss: 0.666875 	T-Acc: 0.595833 	V-Loss: 0.683779 	V-Acc: 0.520000
# ## Test phase...
# Final test Loss: 0.698267
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46483289 	Recall: 0.66577778 	Prec: 0.45476624
#
# ~~Result_C_500_8~~
# EarlyStopping! Epoch 37
# Last: 24 	T-Loss: 0.651859 	T-Acc: 0.634321 	V-Loss: 0.657687 	V-Acc: 0.560000
# ## Test phase...
# Final test Loss: 0.691811
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47550432 	Recall: 0.67911111 	Prec: 0.46274985
#
# ~~Result_C_500_9~~
# EarlyStopping! Epoch 43
# Last: 30 	T-Loss: 0.636925 	T-Acc: 0.657111 	V-Loss: 0.660472 	V-Acc: 0.600000
# ## Test phase...
# Final test Loss: 0.685914
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48366027 	Recall: 0.68977778 	Prec: 0.46888218
#
# ~~Result_C_500_10~~
# EarlyStopping! Epoch 30
# Last: 17 	T-Loss: 0.652229 	T-Acc: 0.630101 	V-Loss: 0.670116 	V-Acc: 0.540000
# ## Test phase...
# Final test Loss: 0.695821
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46656302 	Recall: 0.68355556 	Prec: 0.45828367
#
# ##### TOTAL_DATA 1000 #####
#
# ~~Result_A_1000~~
# EarlyStopping! Epoch 30
# Last: 17 	T-Loss: 0.667829 	T-Acc: 0.593333 	V-Loss: 0.657744 	V-Acc: 0.610000
# ## Test phase...
# Final test Loss: 0.709598
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48736016 	Recall: 0.59822222 	Prec: 0.46064339
#
# ~~Result_B_1000~~
# EarlyStopping! Epoch 44
# Last: 31 	T-Loss: 0.673014 	T-Acc: 0.578889 	V-Loss: 0.667339 	V-Acc: 0.590000
# ## Test phase...
# Final test Loss: 0.703115
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47641103 	Recall: 0.63288889 	Prec: 0.45728966
#
# ~~Result_C_1000_0.25~~
# EarlyStopping! Epoch 44
# Last: 31 	T-Loss: 0.659037 	T-Acc: 0.608889 	V-Loss: 0.645130 	V-Acc: 0.630000
# ## Test phase...
# Final test Loss: 0.704474
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.49687816 	Recall: 0.59200000 	Prec: 0.46704067
#
# ~~Result_C_1000_0.5~~
# EarlyStopping! Epoch 38
# Last: 25 	T-Loss: 0.670279 	T-Acc: 0.595556 	V-Loss: 0.658420 	V-Acc: 0.630000
# ## Test phase...
# Final test Loss: 0.702419
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48851763 	Recall: 0.60088889 	Prec: 0.46174863
#
# ~~Result_C_1000_0.75~~
# EarlyStopping! Epoch 55
# Last: 42 	T-Loss: 0.659975 	T-Acc: 0.605714 	V-Loss: 0.640100 	V-Acc: 0.610000
# ## Test phase...
# Final test Loss: 0.692790
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.50389693 	Recall: 0.61600000 	Prec: 0.47433265
#
# ~~Result_C_1000_1~~
# EarlyStopping! Epoch 39
# Last: 26 	T-Loss: 0.662374 	T-Acc: 0.605000 	V-Loss: 0.642427 	V-Acc: 0.650000
# ## Test phase...
# Final test Loss: 0.698789
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.49036492 	Recall: 0.62488889 	Prec: 0.46556291
#
# ~~Result_C_1000_1.5~~
# EarlyStopping! Epoch 42
# Last: 29 	T-Loss: 0.661229 	T-Acc: 0.593333 	V-Loss: 0.647316 	V-Acc: 0.620000
# ## Test phase...
# Final test Loss: 0.700339
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48542644 	Recall: 0.63466667 	Prec: 0.46333550
#
# ~~Result_C_1000_2~~
# EarlyStopping! Epoch 54
# Last: 41 	T-Loss: 0.643959 	T-Acc: 0.642222 	V-Loss: 0.620082 	V-Acc: 0.650000
# ## Test phase...
# Final test Loss: 0.686779
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.49797701 	Recall: 0.64711111 	Prec: 0.47303444
#
# ~~Result_C_1000_3~~
# EarlyStopping! Epoch 63
# Last: 50 	T-Loss: 0.638981 	T-Acc: 0.652500 	V-Loss: 0.627416 	V-Acc: 0.640000
# ## Test phase...
# Final test Loss: 0.680973
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.50177538 	Recall: 0.66488889 	Prec: 0.47734525
#
# ~~Result_C_1000_4~~
# EarlyStopping! Epoch 73
# Last: 60 	T-Loss: 0.627775 	T-Acc: 0.663333 	V-Loss: 0.617776 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.675966
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.51615841 	Recall: 0.67288889 	Prec: 0.48775773
#
# ~~Result_C_1000_5~~
# EarlyStopping! Epoch 46
# Last: 33 	T-Loss: 0.639204 	T-Acc: 0.652593 	V-Loss: 0.633125 	V-Acc: 0.630000
# ## Test phase...
# Final test Loss: 0.687310
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48271992 	Recall: 0.67911111 	Prec: 0.46699267
#
# ~~Result_C_1000_6~~
# EarlyStopping! Epoch 89
# Last: 76 	T-Loss: 0.611011 	T-Acc: 0.674603 	V-Loss: 0.607393 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.667415
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.54349532 	Recall: 0.68711111 	Prec: 0.50821828
#
# ~~Result_C_1000_7~~
# EarlyStopping! Epoch 53
# Last: 40 	T-Loss: 0.615946 	T-Acc: 0.677778 	V-Loss: 0.623865 	V-Acc: 0.640000
# ## Test phase...
# Final test Loss: 0.681850
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.50642120 	Recall: 0.69066667 	Prec: 0.48290864
#
# ~~Result_C_1000_8~~
# EarlyStopping! Epoch 43
# Last: 30 	T-Loss: 0.614693 	T-Acc: 0.678025 	V-Loss: 0.614569 	V-Acc: 0.670000
# ## Test phase...
# Final test Loss: 0.680836
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.50668960 	Recall: 0.70400000 	Prec: 0.48440367
#
# ~~Result_C_1000_9~~
# EarlyStopping! Epoch 44
# Last: 31 	T-Loss: 0.608541 	T-Acc: 0.683778 	V-Loss: 0.610754 	V-Acc: 0.680000
# ## Test phase...
# Final test Loss: 0.679639
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.51585014 	Recall: 0.72177778 	Prec: 0.49182314
#
# ~~Result_C_1000_10~~
# EarlyStopping! Epoch 60
# Last: 47 	T-Loss: 0.595467 	T-Acc: 0.694040 	V-Loss: 0.600225 	V-Acc: 0.660000
# ## Test phase...
# Final test Loss: 0.674508
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.54414628 	Recall: 0.73422222 	Prec: 0.51113861
#
# ##### TOTAL_DATA 2500 #####
#
# ~~Result_A_2500~~
# EarlyStopping! Epoch 70
# Last: 57 	T-Loss: 0.625164 	T-Acc: 0.657333 	V-Loss: 0.600929 	V-Acc: 0.716000
# ## Test phase...
# Final test Loss: 0.691132
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.52984377 	Recall: 0.56888889 	Prec: 0.49344641
#
# ~~Result_B_2500~~
# EarlyStopping! Epoch 35
# Last: 22 	T-Loss: 0.662617 	T-Acc: 0.615556 	V-Loss: 0.650029 	V-Acc: 0.644000
# ## Test phase...
# Final test Loss: 0.697830
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46143030 	Recall: 0.68177778 	Prec: 0.45519288
#
# ~~Result_C_2500_0.25~~
# EarlyStopping! Epoch 100
# Last: 87 	T-Loss: 0.614759 	T-Acc: 0.675080 	V-Loss: 0.587317 	V-Acc: 0.732000
# ## Test phase...
# Final test Loss: 0.670634
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.55365311 	Recall: 0.58400000 	Prec: 0.51610369
#
# ~~Result_C_2500_0.5~~
# EarlyStopping! Epoch 87
# Last: 74 	T-Loss: 0.634959 	T-Acc: 0.646519 	V-Loss: 0.599897 	V-Acc: 0.704000
# ## Test phase...
# Final test Loss: 0.683435
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.53204173 	Recall: 0.60088889 	Prec: 0.49596478
#
# ~~Result_C_2500_0.75~~
# EarlyStopping! Epoch 49
# Last: 36 	T-Loss: 0.644976 	T-Acc: 0.626968 	V-Loss: 0.611345 	V-Acc: 0.684000
# ## Test phase...
# Final test Loss: 0.689381
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.51299487 	Recall: 0.60888889 	Prec: 0.48070175
#
# ~~Result_C_2500_1~~
# EarlyStopping! Epoch 78
# Last: 65 	T-Loss: 0.624726 	T-Acc: 0.663556 	V-Loss: 0.590892 	V-Acc: 0.744000
# ## Test phase...
# Final test Loss: 0.664036
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.56563543 	Recall: 0.61955556 	Prec: 0.52643505
#
# ~~Result_C_2500_1.5~~
# EarlyStopping! Epoch 70
# Last: 57 	T-Loss: 0.612309 	T-Acc: 0.676267 	V-Loss: 0.582931 	V-Acc: 0.756000
# ## Test phase...
# Final test Loss: 0.652321
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58912959 	Recall: 0.63377778 	Prec: 0.54888376
#
# ~~Result_C_2500_2~~
# EarlyStopping! Epoch 63
# Last: 50 	T-Loss: 0.620773 	T-Acc: 0.673037 	V-Loss: 0.591875 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.658705
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.56908023 	Recall: 0.64266667 	Prec: 0.52889539
#
# ~~Result_C_2500_3~~
# EarlyStopping! Epoch 62
# Last: 49 	T-Loss: 0.603911 	T-Acc: 0.684556 	V-Loss: 0.589668 	V-Acc: 0.740000
# ## Test phase...
# Final test Loss: 0.651313
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58693733 	Recall: 0.65333333 	Prec: 0.54525223
#
# ~~Result_C_2500_4~~
# EarlyStopping! Epoch 47
# Last: 34 	T-Loss: 0.600639 	T-Acc: 0.686133 	V-Loss: 0.588536 	V-Acc: 0.724000
# ## Test phase...
# Final test Loss: 0.653734
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58476942 	Recall: 0.65777778 	Prec: 0.54292003
#
# ~~Result_C_2500_5~~
# EarlyStopping! Epoch 46
# Last: 33 	T-Loss: 0.594615 	T-Acc: 0.688296 	V-Loss: 0.591008 	V-Acc: 0.712000
# ## Test phase...
# Final test Loss: 0.653300
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58262030 	Recall: 0.68711111 	Prec: 0.53980447
#
# ~~Result_C_2500_6~~
# EarlyStopping! Epoch 78
# Last: 65 	T-Loss: 0.576635 	T-Acc: 0.702413 	V-Loss: 0.569892 	V-Acc: 0.716000
# ## Test phase...
# Final test Loss: 0.637764
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61276483 	Recall: 0.70666667 	Prec: 0.56623932
#
# ~~Result_C_2500_7~~
# EarlyStopping! Epoch 56
# Last: 43 	T-Loss: 0.581783 	T-Acc: 0.691833 	V-Loss: 0.591197 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.645632
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.59832553 	Recall: 0.72266667 	Prec: 0.55230978
#
# ~~Result_C_2500_8~~
# EarlyStopping! Epoch 50
# Last: 37 	T-Loss: 0.583368 	T-Acc: 0.698173 	V-Loss: 0.597709 	V-Acc: 0.680000
# ## Test phase...
# Final test Loss: 0.653894
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58645195 	Recall: 0.72977778 	Prec: 0.54227213
#
# ~~Result_C_2500_9~~
# EarlyStopping! Epoch 25
# Last: 12 	T-Loss: 0.608034 	T-Acc: 0.686356 	V-Loss: 0.612046 	V-Acc: 0.672000
# ## Test phase...
# Final test Loss: 0.675322
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.52690199 	Recall: 0.70400000 	Prec: 0.49748744
#
# ~~Result_C_2500_10~~
# EarlyStopping! Epoch 32
# Last: 19 	T-Loss: 0.587629 	T-Acc: 0.697131 	V-Loss: 0.601197 	V-Acc: 0.708000
# ## Test phase...
# Final test Loss: 0.671804
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.54865232 	Recall: 0.69600000 	Prec: 0.51243455
#
# ##### TOTAL_DATA 5000 #####
#
# ~~Result_A_5000~~
# EarlyStopping! Epoch 105
# Last: 92 	T-Loss: 0.576914 	T-Acc: 0.712667 	V-Loss: 0.558405 	V-Acc: 0.752000
# ## Test phase...
# Final test Loss: 0.665463
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58252381 	Recall: 0.62133333 	Prec: 0.54312354
#
# ~~Result_B_5000~~
# EarlyStopping! Epoch 40
# Last: 27 	T-Loss: 0.635026 	T-Acc: 0.674444 	V-Loss: 0.658081 	V-Acc: 0.608000
# ## Test phase...
# Final test Loss: 0.703571
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46653385 	Recall: 0.69600000 	Prec: 0.46004700
#
# ~~Result_C_5000_0.25~~
# EarlyStopping! Epoch 85
# Last: 72 	T-Loss: 0.589303 	T-Acc: 0.693156 	V-Loss: 0.559200 	V-Acc: 0.742000
# ## Test phase...
# Final test Loss: 0.655444
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58460018 	Recall: 0.62844444 	Prec: 0.54468413
#
# ~~Result_C_5000_0.5~~
# EarlyStopping! Epoch 99
# Last: 86 	T-Loss: 0.591731 	T-Acc: 0.698074 	V-Loss: 0.564192 	V-Acc: 0.734000
# ## Test phase...
# Final test Loss: 0.645945
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60186679 	Recall: 0.64088889 	Prec: 0.56152648
#
# ~~Result_C_5000_0.75~~
# EarlyStopping! Epoch 71
# Last: 58 	T-Loss: 0.599045 	T-Acc: 0.693714 	V-Loss: 0.576649 	V-Acc: 0.732000
# ## Test phase...
# Final test Loss: 0.648813
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.59858691 	Recall: 0.65244444 	Prec: 0.55690440
#
# ~~Result_C_5000_1~~
# EarlyStopping! Epoch 57
# Last: 44 	T-Loss: 0.605467 	T-Acc: 0.688333 	V-Loss: 0.582271 	V-Acc: 0.712000
# ## Test phase...
# Final test Loss: 0.651429
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.59527927 	Recall: 0.65155556 	Prec: 0.55362538
#
# ~~Result_C_5000_1.5~~
# EarlyStopping! Epoch 72
# Last: 59 	T-Loss: 0.589610 	T-Acc: 0.696889 	V-Loss: 0.570254 	V-Acc: 0.724000
# ## Test phase...
# Final test Loss: 0.635185
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62289001 	Recall: 0.67288889 	Prec: 0.58007663
#
# ~~Result_C_5000_2~~
# EarlyStopping! Epoch 76
# Last: 63 	T-Loss: 0.585791 	T-Acc: 0.698667 	V-Loss: 0.572787 	V-Acc: 0.730000
# ## Test phase...
# Final test Loss: 0.634320
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62358427 	Recall: 0.69333333 	Prec: 0.57820608
#
# ~~Result_C_5000_3~~
# EarlyStopping! Epoch 42
# Last: 29 	T-Loss: 0.590509 	T-Acc: 0.690778 	V-Loss: 0.595998 	V-Acc: 0.702000
# ## Test phase...
# Final test Loss: 0.642371
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60076422 	Recall: 0.69511111 	Prec: 0.55579247
#
# ~~Result_C_5000_4~~
# EarlyStopping! Epoch 68
# Last: 55 	T-Loss: 0.574101 	T-Acc: 0.701511 	V-Loss: 0.581237 	V-Acc: 0.686000
# ## Test phase...
# Final test Loss: 0.630747
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62538563 	Recall: 0.71022222 	Prec: 0.57814761
#
# ~~Result_C_5000_5~~
# EarlyStopping! Epoch 56
# Last: 43 	T-Loss: 0.572732 	T-Acc: 0.698926 	V-Loss: 0.580843 	V-Acc: 0.692000
# ## Test phase...
# Final test Loss: 0.633229
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61949431 	Recall: 0.73422222 	Prec: 0.57044199
#
# ~~Result_C_5000_6~~
# EarlyStopping! Epoch 47
# Last: 34 	T-Loss: 0.569140 	T-Acc: 0.706603 	V-Loss: 0.590143 	V-Acc: 0.694000
# ## Test phase...
# Final test Loss: 0.635753
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61854653 	Recall: 0.75377778 	Prec: 0.56836461
#
# ~~Result_C_5000_7~~
# EarlyStopping! Epoch 42
# Last: 29 	T-Loss: 0.569965 	T-Acc: 0.703944 	V-Loss: 0.598788 	V-Acc: 0.690000
# ## Test phase...
# Final test Loss: 0.640654
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60503359 	Recall: 0.72800000 	Prec: 0.55790191
#
# ~~Result_C_5000_8~~
# EarlyStopping! Epoch 89
# Last: 76 	T-Loss: 0.564209 	T-Acc: 0.707432 	V-Loss: 0.600829 	V-Acc: 0.664000
# ## Test phase...
# Final test Loss: 0.639202
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60928203 	Recall: 0.74666667 	Prec: 0.56074766
#
# ~~Result_C_5000_9~~
# EarlyStopping! Epoch 49
# Last: 36 	T-Loss: 0.562850 	T-Acc: 0.707422 	V-Loss: 0.599879 	V-Acc: 0.672000
# ## Test phase...
# Final test Loss: 0.641324
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60354114 	Recall: 0.73155556 	Prec: 0.55645707
#
# ~~Result_C_5000_10~~
# EarlyStopping! Epoch 52
# Last: 39 	T-Loss: 0.560589 	T-Acc: 0.709212 	V-Loss: 0.605934 	V-Acc: 0.666000
# ## Test phase...
# Final test Loss: 0.639475
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61593983 	Recall: 0.78044444 	Prec: 0.56499356
#
# ##### TOTAL_DATA 7500 #####
#
# ~~Result_A_7500~~
# EarlyStopping! Epoch 72
# Last: 59 	T-Loss: 0.570268 	T-Acc: 0.713926 	V-Loss: 0.564810 	V-Acc: 0.708000
# ## Test phase...
# Final test Loss: 0.656070
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58948040 	Recall: 0.62311111 	Prec: 0.55023548
#
# ~~Result_B_7500~~
# EarlyStopping! Epoch 32
# Last: 19 	T-Loss: 0.631744 	T-Acc: 0.666222 	V-Loss: 0.658593 	V-Acc: 0.590667
# ## Test phase...
# Final test Loss: 0.698872
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47239693 	Recall: 0.69955556 	Prec: 0.46375958
#
# ~~Result_C_7500_0.25~~
# EarlyStopping! Epoch 78
# Last: 65 	T-Loss: 0.574309 	T-Acc: 0.711187 	V-Loss: 0.559508 	V-Acc: 0.734667
# ## Test phase...
# Final test Loss: 0.639477
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61243355 	Recall: 0.63911111 	Prec: 0.57336523
#
# ~~Result_C_7500_0.5~~
# EarlyStopping! Epoch 91
# Last: 78 	T-Loss: 0.584250 	T-Acc: 0.699160 	V-Loss: 0.561754 	V-Acc: 0.718667
# ## Test phase...
# Final test Loss: 0.631377
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62431519 	Recall: 0.64800000 	Prec: 0.58554217
#
# ~~Result_C_7500_0.75~~
# EarlyStopping! Epoch 91
# Last: 78 	T-Loss: 0.581484 	T-Acc: 0.702785 	V-Loss: 0.560185 	V-Acc: 0.730667
# ## Test phase...
# Final test Loss: 0.625307
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63848971 	Recall: 0.67733333 	Prec: 0.59671104
#
# ~~Result_C_7500_1~~
# EarlyStopping! Epoch 62
# Last: 49 	T-Loss: 0.586575 	T-Acc: 0.697481 	V-Loss: 0.562998 	V-Acc: 0.712000
# ## Test phase...
# Final test Loss: 0.628281
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63687721 	Recall: 0.68177778 	Prec: 0.59411309
#
# ~~Result_C_7500_1.5~~
# EarlyStopping! Epoch 71
# Last: 58 	T-Loss: 0.578975 	T-Acc: 0.697659 	V-Loss: 0.569208 	V-Acc: 0.713333
# ## Test phase...
# Final test Loss: 0.619828
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.66533389 	Recall: 0.75466667 	Prec: 0.61299639
#
# ~~Result_C_7500_2~~
# EarlyStopping! Epoch 54
# Last: 41 	T-Loss: 0.580873 	T-Acc: 0.698667 	V-Loss: 0.575974 	V-Acc: 0.690667
# ## Test phase...
# Final test Loss: 0.624057
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64141233 	Recall: 0.68888889 	Prec: 0.59799383
#
# ~~Result_C_7500_3~~
# EarlyStopping! Epoch 63
# Last: 50 	T-Loss: 0.574068 	T-Acc: 0.700556 	V-Loss: 0.582606 	V-Acc: 0.714667
# ## Test phase...
# Final test Loss: 0.626615
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63476576 	Recall: 0.69955556 	Prec: 0.58907186
#
# ~~Result_C_7500_4~~
# EarlyStopping! Epoch 54
# Last: 41 	T-Loss: 0.570090 	T-Acc: 0.702489 	V-Loss: 0.586161 	V-Acc: 0.685333
# ## Test phase...
# Final test Loss: 0.619376
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64450707 	Recall: 0.72177778 	Prec: 0.59618209
#
# ~~Result_C_7500_5~~
# EarlyStopping! Epoch 55
# Last: 42 	T-Loss: 0.563703 	T-Acc: 0.705753 	V-Loss: 0.589426 	V-Acc: 0.681333
# ## Test phase...
# Final test Loss: 0.625013
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63184241 	Recall: 0.70044444 	Prec: 0.58587361
#
# ~~Result_C_7500_6~~
# EarlyStopping! Epoch 59
# Last: 46 	T-Loss: 0.562828 	T-Acc: 0.705799 	V-Loss: 0.588193 	V-Acc: 0.677333
# ## Test phase...
# Final test Loss: 0.616874
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64005761 	Recall: 0.71111111 	Prec: 0.59303188
#
# ~~Result_C_7500_7~~
# EarlyStopping! Epoch 26
# Last: 13 	T-Loss: 0.577633 	T-Acc: 0.699222 	V-Loss: 0.611073 	V-Acc: 0.648000
# ## Test phase...
# Final test Loss: 0.647803
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60199819 	Recall: 0.79466667 	Prec: 0.55390335
#
# ~~Result_C_7500_8~~
# EarlyStopping! Epoch 38
# Last: 25 	T-Loss: 0.561894 	T-Acc: 0.707095 	V-Loss: 0.603995 	V-Acc: 0.652000
# ## Test phase...
# Final test Loss: 0.628753
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62415916 	Recall: 0.70844444 	Prec: 0.57711803
#
# ~~Result_C_7500_9~~
# EarlyStopping! Epoch 40
# Last: 27 	T-Loss: 0.561192 	T-Acc: 0.706948 	V-Loss: 0.602752 	V-Acc: 0.673333
# ## Test phase...
# Final test Loss: 0.634936
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61574534 	Recall: 0.72000000 	Prec: 0.56802244
#
# ~~Result_C_7500_10~~
# EarlyStopping! Epoch 40
# Last: 27 	T-Loss: 0.557529 	T-Acc: 0.709158 	V-Loss: 0.616645 	V-Acc: 0.641333
# ## Test phase...
# Final test Loss: 0.627295
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63324401 	Recall: 0.78133333 	Prec: 0.57943309
#
# ##### TOTAL_DATA 12389 #####
#
# ~~Result_A_12389~~
# EarlyStopping! Epoch 88
# Last: 75 	T-Loss: 0.554095 	T-Acc: 0.724360 	V-Loss: 0.541437 	V-Acc: 0.736253
# ## Test phase...
# Final test Loss: 0.641469
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61258491 	Recall: 0.65511111 	Prec: 0.57131783
#
# ~~Result_B_12389~~
# EarlyStopping! Epoch 24
# Last: 11 	T-Loss: 0.631418 	T-Acc: 0.668191 	V-Loss: 0.664401 	V-Acc: 0.580448
# ## Test phase...
# Final test Loss: 0.699914
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47126061 	Recall: 0.70044444 	Prec: 0.46325691
#
# ~~Result_C_12389_0.25~~
# EarlyStopping! Epoch 72
# Last: 59 	T-Loss: 0.569645 	T-Acc: 0.708914 	V-Loss: 0.549508 	V-Acc: 0.723014
# ## Test phase...
# Final test Loss: 0.631071
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61955325 	Recall: 0.63200000 	Prec: 0.58278689
#
# ~~Result_C_12389_0.5~~
# EarlyStopping! Epoch 66
# Last: 53 	T-Loss: 0.576065 	T-Acc: 0.703588 	V-Loss: 0.553490 	V-Acc: 0.712831
# ## Test phase...
# Final test Loss: 0.625144
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63368390 	Recall: 0.65244444 	Prec: 0.59577922
#
# ~~Result_C_12389_0.75~~
# EarlyStopping! Epoch 77
# Last: 64 	T-Loss: 0.574145 	T-Acc: 0.702547 	V-Loss: 0.552266 	V-Acc: 0.714868
# ## Test phase...
# Final test Loss: 0.619338
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64489750 	Recall: 0.66933333 	Prec: 0.60579244
#
# ~~Result_C_12389_1~~
# EarlyStopping! Epoch 133
# Last: 120 	T-Loss: 0.569717 	T-Acc: 0.706030 	V-Loss: 0.549014 	V-Acc: 0.726069
# ## Test phase...
# Final test Loss: 0.612002
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.66074039 	Recall: 0.70400000 	Prec: 0.61730320
#
# ~~Result_C_12389_1.5~~
# EarlyStopping! Epoch 53
# Last: 40 	T-Loss: 0.574996 	T-Acc: 0.704409 	V-Loss: 0.567576 	V-Acc: 0.697556
# ## Test phase...
# Final test Loss: 0.626827
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63812048 	Recall: 0.69155556 	Prec: 0.59389313
#
# ~~Result_C_12389_2~~
# EarlyStopping! Epoch 37
# Last: 24 	T-Loss: 0.580324 	T-Acc: 0.698314 	V-Loss: 0.577386 	V-Acc: 0.706721
# ## Test phase...
# Final test Loss: 0.629427
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63109084 	Recall: 0.69155556 	Prec: 0.58628485
#
# ~~Result_C_12389_3~~
# EarlyStopping! Epoch 36
# Last: 23 	T-Loss: 0.574096 	T-Acc: 0.698687 	V-Loss: 0.588975 	V-Acc: 0.684318
# ## Test phase...
# Final test Loss: 0.625263
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63389631 	Recall: 0.70311111 	Prec: 0.58766716
#
# ~~Result_C_12389_4~~
# EarlyStopping! Epoch 62
# Last: 49 	T-Loss: 0.564545 	T-Acc: 0.704351 	V-Loss: 0.581121 	V-Acc: 0.686354
# ## Test phase...
# Final test Loss: 0.616883
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64502031 	Recall: 0.71466667 	Prec: 0.59776952
#
# ~~Result_C_12389_5~~
# EarlyStopping! Epoch 47
# Last: 34 	T-Loss: 0.560955 	T-Acc: 0.707362 	V-Loss: 0.592182 	V-Acc: 0.678208
# ## Test phase...
# Final test Loss: 0.615498
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64535571 	Recall: 0.74133333 	Prec: 0.59444048
#
# ~~Result_C_12389_6~~
# EarlyStopping! Epoch 72
# Last: 59 	T-Loss: 0.559596 	T-Acc: 0.709764 	V-Loss: 0.597846 	V-Acc: 0.654786
# ## Test phase...
# Final test Loss: 0.620797
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63680067 	Recall: 0.72800000 	Prec: 0.58751793
#
# ~~Result_C_12389_7~~
# EarlyStopping! Epoch 40
# Last: 27 	T-Loss: 0.559807 	T-Acc: 0.709455 	V-Loss: 0.611477 	V-Acc: 0.649695
# ## Test phase...
# Final test Loss: 0.632943
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62215136 	Recall: 0.76000000 	Prec: 0.57114228
#
# ~~Result_C_12389_8~~
# EarlyStopping! Epoch 36
# Last: 23 	T-Loss: 0.557307 	T-Acc: 0.709614 	V-Loss: 0.614638 	V-Acc: 0.641548
# ## Test phase...
# Final test Loss: 0.629304
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62441499 	Recall: 0.74044444 	Prec: 0.57448276
#
# ~~Result_C_12389_9~~
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/loss.py:498: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# EarlyStopping! Epoch 52
# Last: 39 	T-Loss: 0.555052 	T-Acc: 0.712717 	V-Loss: 0.606468 	V-Acc: 0.664969
# ## Test phase...
# Final test Loss: 0.628227
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62770583 	Recall: 0.76266667 	Prec: 0.57583893
#
# ~~Result_C_12389_10~~
# EarlyStopping! Epoch 33
# Last: 20 	T-Loss: 0.554769 	T-Acc: 0.713001 	V-Loss: 0.619492 	V-Acc: 0.646640
# ## Test phase...
# Final test Loss: 0.641569
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61337394 	Recall: 0.75200000 	Prec: 0.56400000
#
# ############################
# ### START RANDOM_SEED 5 ###
# ############################
#
# ##### TOTAL_DATA 500 #####
#
# ~~Result_A_500~~
# EarlyStopping! Epoch 30
# Last: 17 	T-Loss: 0.672133 	T-Acc: 0.595556 	V-Loss: 0.711188 	V-Acc: 0.500000
# ## Test phase...
# Final test Loss: 0.714548
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47594768 	Recall: 0.63733333 	Prec: 0.45756222
#
# ~~Result_B_500~~
# EarlyStopping! Epoch 26
# Last: 13 	T-Loss: 0.687022 	T-Acc: 0.511111 	V-Loss: 0.700297 	V-Acc: 0.540000
# ## Test phase...
# Final test Loss: 0.698363
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47949100 	Recall: 0.60888889 	Prec: 0.45636243
#
# ~~Result_C_500_0.25~~
# EarlyStopping! Epoch 28
# Last: 15 	T-Loss: 0.672954 	T-Acc: 0.593250 	V-Loss: 0.702997 	V-Acc: 0.520000
# ## Test phase...
# Final test Loss: 0.710987
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47557861 	Recall: 0.63200000 	Prec: 0.45664740
#
# ~~Result_C_500_0.5~~
# EarlyStopping! Epoch 30
# Last: 17 	T-Loss: 0.674753 	T-Acc: 0.589630 	V-Loss: 0.699572 	V-Acc: 0.480000
# ## Test phase...
# Final test Loss: 0.707262
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47699038 	Recall: 0.62222222 	Prec: 0.45632334
#
# ~~Result_C_500_0.75~~
# EarlyStopping! Epoch 20
# Last: 7 	T-Loss: 0.683487 	T-Acc: 0.578680 	V-Loss: 0.706685 	V-Acc: 0.500000
# ## Test phase...
# Final test Loss: 0.706360
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47416118 	Recall: 0.62311111 	Prec: 0.45460441
#
# ~~Result_C_500_1~~
# EarlyStopping! Epoch 40
# Last: 27 	T-Loss: 0.678509 	T-Acc: 0.572222 	V-Loss: 0.696430 	V-Acc: 0.520000
# ## Test phase...
# Final test Loss: 0.699921
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48587788 	Recall: 0.61333333 	Prec: 0.46122995
#
# ~~Result_C_500_1.5~~
# EarlyStopping! Epoch 15
# Last: 2 	T-Loss: 0.689660 	T-Acc: 0.549333 	V-Loss: 0.700710 	V-Acc: 0.500000
# ## Test phase...
# Final test Loss: 0.701871
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47179547 	Recall: 0.61422222 	Prec: 0.45192937
#
# ~~Result_C_500_2~~
# EarlyStopping! Epoch 49
# Last: 36 	T-Loss: 0.667437 	T-Acc: 0.597037 	V-Loss: 0.697472 	V-Acc: 0.480000
# ## Test phase...
# Final test Loss: 0.700770
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48260919 	Recall: 0.64000000 	Prec: 0.46213094
#
# ~~Result_C_500_3~~
# EarlyStopping! Epoch 40
# Last: 27 	T-Loss: 0.665562 	T-Acc: 0.588889 	V-Loss: 0.683656 	V-Acc: 0.500000
# ## Test phase...
# Final test Loss: 0.699031
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47208710 	Recall: 0.65066667 	Prec: 0.45692884
#
# ~~Result_C_500_4~~
# EarlyStopping! Epoch 61
# Last: 48 	T-Loss: 0.645075 	T-Acc: 0.648000 	V-Loss: 0.658960 	V-Acc: 0.500000
# ## Test phase...
# Final test Loss: 0.689479
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48284823 	Recall: 0.66311111 	Prec: 0.46508728
#
# ~~Result_C_500_5~~
# EarlyStopping! Epoch 54
# Last: 41 	T-Loss: 0.648245 	T-Acc: 0.647407 	V-Loss: 0.658350 	V-Acc: 0.520000
# ## Test phase...
# Final test Loss: 0.686290
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47732589 	Recall: 0.67288889 	Prec: 0.46299694
#
# ~~Result_C_500_6~~
# EarlyStopping! Epoch 48
# Last: 35 	T-Loss: 0.657128 	T-Acc: 0.613651 	V-Loss: 0.675621 	V-Acc: 0.560000
# ## Test phase...
# Final test Loss: 0.692677
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46272837 	Recall: 0.67022222 	Prec: 0.45421687
#
# ~~Result_C_500_7~~
# EarlyStopping! Epoch 40
# Last: 27 	T-Loss: 0.659152 	T-Acc: 0.611389 	V-Loss: 0.680489 	V-Acc: 0.560000
# ## Test phase...
# Final test Loss: 0.692942
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46612982 	Recall: 0.67022222 	Prec: 0.45614035
#
# ~~Result_C_500_8~~
# EarlyStopping! Epoch 56
# Last: 43 	T-Loss: 0.638744 	T-Acc: 0.653333 	V-Loss: 0.652391 	V-Acc: 0.580000
# ## Test phase...
# Final test Loss: 0.685896
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48067191 	Recall: 0.68355556 	Prec: 0.46634324
#
# ~~Result_C_500_9~~
# EarlyStopping! Epoch 60
# Last: 47 	T-Loss: 0.647277 	T-Acc: 0.636667 	V-Loss: 0.664049 	V-Acc: 0.580000
# ## Test phase...
# Final test Loss: 0.689987
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47366734 	Recall: 0.68177778 	Prec: 0.46204819
#
# ~~Result_C_500_10~~
# EarlyStopping! Epoch 46
# Last: 33 	T-Loss: 0.647988 	T-Acc: 0.641616 	V-Loss: 0.662933 	V-Acc: 0.540000
# ## Test phase...
# Final test Loss: 0.690281
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47159012 	Recall: 0.68266667 	Prec: 0.46098439
#
# ##### TOTAL_DATA 1000 #####
#
# ~~Result_A_1000~~
# EarlyStopping! Epoch 22
# Last: 9 	T-Loss: 0.673933 	T-Acc: 0.591111 	V-Loss: 0.661369 	V-Acc: 0.630000
# ## Test phase...
# Final test Loss: 0.715000
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47548370 	Recall: 0.63733333 	Prec: 0.45727041
#
# ~~Result_B_1000~~
# EarlyStopping! Epoch 22
# Last: 9 	T-Loss: 0.685828 	T-Acc: 0.568889 	V-Loss: 0.675270 	V-Acc: 0.630000
# ## Test phase...
# Final test Loss: 0.703603
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47455494 	Recall: 0.63733333 	Prec: 0.45668790
#
# ~~Result_C_1000_0.25~~
# EarlyStopping! Epoch 45
# Last: 32 	T-Loss: 0.668834 	T-Acc: 0.597333 	V-Loss: 0.654645 	V-Acc: 0.630000
# ## Test phase...
# Final test Loss: 0.703100
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48734298 	Recall: 0.60533333 	Prec: 0.46138211
#
# ~~Result_C_1000_0.5~~
# EarlyStopping! Epoch 65
# Last: 52 	T-Loss: 0.663743 	T-Acc: 0.594074 	V-Loss: 0.648513 	V-Acc: 0.610000
# ## Test phase...
# Final test Loss: 0.698510
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.49314803 	Recall: 0.60444444 	Prec: 0.46543463
#
# ~~Result_C_1000_0.75~~
# EarlyStopping! Epoch 44
# Last: 31 	T-Loss: 0.668484 	T-Acc: 0.584762 	V-Loss: 0.651695 	V-Acc: 0.630000
# ## Test phase...
# Final test Loss: 0.696350
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48636128 	Recall: 0.61866667 	Prec: 0.46215139
#
# ~~Result_C_1000_1~~
# EarlyStopping! Epoch 62
# Last: 49 	T-Loss: 0.660511 	T-Acc: 0.602778 	V-Loss: 0.646890 	V-Acc: 0.610000
# ## Test phase...
# Final test Loss: 0.696358
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.49282022 	Recall: 0.62222222 	Prec: 0.46697799
#
# ~~Result_C_1000_1.5~~
# EarlyStopping! Epoch 72
# Last: 59 	T-Loss: 0.650282 	T-Acc: 0.623556 	V-Loss: 0.632139 	V-Acc: 0.650000
# ## Test phase...
# Final test Loss: 0.689044
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.49941700 	Recall: 0.63555556 	Prec: 0.47288360
#
# ~~Result_C_1000_2~~
# EarlyStopping! Epoch 61
# Last: 48 	T-Loss: 0.649308 	T-Acc: 0.624815 	V-Loss: 0.631764 	V-Acc: 0.620000
# ## Test phase...
# Final test Loss: 0.688190
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.49231460 	Recall: 0.64888889 	Prec: 0.46945338
#
# ~~Result_C_1000_3~~
# EarlyStopping! Epoch 60
# Last: 47 	T-Loss: 0.657763 	T-Acc: 0.611944 	V-Loss: 0.643006 	V-Acc: 0.600000
# ## Test phase...
# Final test Loss: 0.691140
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47633333 	Recall: 0.66222222 	Prec: 0.46101485
#
# ~~Result_C_1000_4~~
# EarlyStopping! Epoch 50
# Last: 37 	T-Loss: 0.650337 	T-Acc: 0.631333 	V-Loss: 0.641093 	V-Acc: 0.620000
# ## Test phase...
# Final test Loss: 0.686534
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.48357735 	Recall: 0.66488889 	Prec: 0.46575342
#
# ~~Result_C_1000_5~~
# EarlyStopping! Epoch 33
# Last: 20 	T-Loss: 0.648488 	T-Acc: 0.636852 	V-Loss: 0.638580 	V-Acc: 0.640000
# ## Test phase...
# Final test Loss: 0.686324
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.47887997 	Recall: 0.67200000 	Prec: 0.46380368
#
# ~~Result_C_1000_6~~
# EarlyStopping! Epoch 58
# Last: 45 	T-Loss: 0.620377 	T-Acc: 0.667619 	V-Loss: 0.615259 	V-Acc: 0.710000
# ## Test phase...
# Final test Loss: 0.675002
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.51780227 	Recall: 0.68444444 	Prec: 0.48982188
#
# ~~Result_C_1000_7~~
# EarlyStopping! Epoch 52
# Last: 39 	T-Loss: 0.621646 	T-Acc: 0.667500 	V-Loss: 0.618138 	V-Acc: 0.670000
# ## Test phase...
# Final test Loss: 0.679944
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.50719769 	Recall: 0.68800000 	Prec: 0.48314607
#
# ~~Result_C_1000_8~~
# EarlyStopping! Epoch 55
# Last: 42 	T-Loss: 0.618256 	T-Acc: 0.672840 	V-Loss: 0.623001 	V-Acc: 0.650000
# ## Test phase...
# Final test Loss: 0.679427
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.50819105 	Recall: 0.69955556 	Prec: 0.48490450
#
# ~~Result_C_1000_9~~
# EarlyStopping! Epoch 60
# Last: 47 	T-Loss: 0.596906 	T-Acc: 0.688556 	V-Loss: 0.594287 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.667987
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.55489419 	Recall: 0.72888889 	Prec: 0.51833123
#
# ~~Result_C_1000_10~~
# EarlyStopping! Epoch 61
# Last: 48 	T-Loss: 0.593448 	T-Acc: 0.689192 	V-Loss: 0.599442 	V-Acc: 0.690000
# ## Test phase...
# Final test Loss: 0.670292
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.55373046 	Recall: 0.73600000 	Prec: 0.51782364
#
# ##### TOTAL_DATA 2500 #####
#
# ~~Result_A_2500~~
# EarlyStopping! Epoch 76
# Last: 63 	T-Loss: 0.618259 	T-Acc: 0.666222 	V-Loss: 0.593632 	V-Acc: 0.736000
# ## Test phase...
# Final test Loss: 0.684810
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.53145942 	Recall: 0.56444444 	Prec: 0.49493375
#
# ~~Result_B_2500~~
# EarlyStopping! Epoch 76
# Last: 63 	T-Loss: 0.639015 	T-Acc: 0.665333 	V-Loss: 0.639866 	V-Acc: 0.648000
# ## Test phase...
# Final test Loss: 0.694560
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46533873 	Recall: 0.69422222 	Prec: 0.45914168
#
# ~~Result_C_2500_0.25~~
# EarlyStopping! Epoch 72
# Last: 59 	T-Loss: 0.643370 	T-Acc: 0.630643 	V-Loss: 0.611558 	V-Acc: 0.716000
# ## Test phase...
# Final test Loss: 0.690113
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.52012369 	Recall: 0.58666667 	Prec: 0.48529412
#
# ~~Result_C_2500_0.5~~
# EarlyStopping! Epoch 51
# Last: 38 	T-Loss: 0.636841 	T-Acc: 0.634370 	V-Loss: 0.604344 	V-Acc: 0.708000
# ## Test phase...
# Final test Loss: 0.682932
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.52490162 	Recall: 0.59911111 	Prec: 0.48982558
#
# ~~Result_C_2500_0.75~~
# EarlyStopping! Epoch 63
# Last: 50 	T-Loss: 0.630940 	T-Acc: 0.656171 	V-Loss: 0.595657 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.675128
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.53690579 	Recall: 0.60977778 	Prec: 0.50036470
#
# ~~Result_C_2500_1~~
# EarlyStopping! Epoch 93
# Last: 80 	T-Loss: 0.627475 	T-Acc: 0.659333 	V-Loss: 0.592188 	V-Acc: 0.732000
# ## Test phase...
# Final test Loss: 0.666478
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.55649911 	Recall: 0.61777778 	Prec: 0.51788376
#
# ~~Result_C_2500_1.5~~
# EarlyStopping! Epoch 50
# Last: 37 	T-Loss: 0.642300 	T-Acc: 0.632533 	V-Loss: 0.611035 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.677422
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.52316094 	Recall: 0.63200000 	Prec: 0.49000689
#
# ~~Result_C_2500_2~~
# EarlyStopping! Epoch 53
# Last: 40 	T-Loss: 0.631767 	T-Acc: 0.663111 	V-Loss: 0.606694 	V-Acc: 0.716000
# ## Test phase...
# Final test Loss: 0.670495
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.54221387 	Recall: 0.65155556 	Prec: 0.50586611
#
# ~~Result_C_2500_3~~
# EarlyStopping! Epoch 45
# Last: 32 	T-Loss: 0.617906 	T-Acc: 0.678778 	V-Loss: 0.594752 	V-Acc: 0.724000
# ## Test phase...
# Final test Loss: 0.664569
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.55835703 	Recall: 0.65866667 	Prec: 0.51927120
#
# ~~Result_C_2500_4~~
# EarlyStopping! Epoch 59
# Last: 46 	T-Loss: 0.595912 	T-Acc: 0.691556 	V-Loss: 0.586697 	V-Acc: 0.732000
# ## Test phase...
# Final test Loss: 0.651187
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58240785 	Recall: 0.66844444 	Prec: 0.54022989
#
# ~~Result_C_2500_5~~
# EarlyStopping! Epoch 44
# Last: 31 	T-Loss: 0.603659 	T-Acc: 0.680370 	V-Loss: 0.596162 	V-Acc: 0.712000
# ## Test phase...
# Final test Loss: 0.657645
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.56956254 	Recall: 0.70311111 	Prec: 0.52874332
#
# ~~Result_C_2500_6~~
# EarlyStopping! Epoch 54
# Last: 41 	T-Loss: 0.585299 	T-Acc: 0.698286 	V-Loss: 0.594728 	V-Acc: 0.708000
# ## Test phase...
# Final test Loss: 0.646414
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.59967937 	Recall: 0.72177778 	Prec: 0.55351057
#
# ~~Result_C_2500_7~~
# EarlyStopping! Epoch 39
# Last: 26 	T-Loss: 0.589371 	T-Acc: 0.692333 	V-Loss: 0.590523 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.658107
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.57068262 	Recall: 0.69155556 	Prec: 0.52961198
#
# ~~Result_C_2500_8~~
# EarlyStopping! Epoch 34
# Last: 21 	T-Loss: 0.593277 	T-Acc: 0.689185 	V-Loss: 0.589520 	V-Acc: 0.684000
# ## Test phase...
# Final test Loss: 0.664753
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.55608679 	Recall: 0.71022222 	Prec: 0.51849448
#
# ~~Result_C_2500_9~~
# EarlyStopping! Epoch 62
# Last: 49 	T-Loss: 0.569279 	T-Acc: 0.704089 	V-Loss: 0.584606 	V-Acc: 0.684000
# ## Test phase...
# Final test Loss: 0.642000
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60655365 	Recall: 0.73244444 	Prec: 0.55902307
#
# ~~Result_C_2500_10~~
# EarlyStopping! Epoch 48
# Last: 35 	T-Loss: 0.569470 	T-Acc: 0.702545 	V-Loss: 0.583094 	V-Acc: 0.708000
# ## Test phase...
# Final test Loss: 0.642295
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60429375 	Recall: 0.72533333 	Prec: 0.55737705
#
# ##### TOTAL_DATA 5000 #####
#
# ~~Result_A_5000~~
# EarlyStopping! Epoch 98
# Last: 85 	T-Loss: 0.564831 	T-Acc: 0.715778 	V-Loss: 0.545717 	V-Acc: 0.758000
# ## Test phase...
# Final test Loss: 0.656578
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.59201317 	Recall: 0.63911111 	Prec: 0.55138037
#
# ~~Result_B_5000~~
# EarlyStopping! Epoch 29
# Last: 16 	T-Loss: 0.654342 	T-Acc: 0.627111 	V-Loss: 0.659952 	V-Acc: 0.600000
# ## Test phase...
# Final test Loss: 0.694365
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46140520 	Recall: 0.68800000 	Prec: 0.45609900
#
# ~~Result_C_5000_0.25~~
# EarlyStopping! Epoch 98
# Last: 85 	T-Loss: 0.583823 	T-Acc: 0.700978 	V-Loss: 0.558437 	V-Acc: 0.746000
# ## Test phase...
# Final test Loss: 0.646872
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60187192 	Recall: 0.64177778 	Prec: 0.56143079
#
# ~~Result_C_5000_0.5~~
# EarlyStopping! Epoch 91
# Last: 78 	T-Loss: 0.591313 	T-Acc: 0.699407 	V-Loss: 0.563897 	V-Acc: 0.746000
# ## Test phase...
# Final test Loss: 0.643844
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60599762 	Recall: 0.64800000 	Prec: 0.56511628
#
# ~~Result_C_5000_0.75~~
# EarlyStopping! Epoch 74
# Last: 61 	T-Loss: 0.593303 	T-Acc: 0.696000 	V-Loss: 0.564709 	V-Acc: 0.732000
# ## Test phase...
# Final test Loss: 0.639455
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60806750 	Recall: 0.65422222 	Prec: 0.56658968
#
# ~~Result_C_5000_1~~
# EarlyStopping! Epoch 69
# ...
#
# ~~Result_C_2500_10~~
# EarlyStopping! Epoch 84
# Last: 71 	T-Loss: 0.564069 	T-Acc: 0.706707 	V-Loss: 0.575434 	V-Acc: 0.712000
# ## Test phase...
# Final test Loss: 0.637411
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61498855 	Recall: 0.74666667 	Prec: 0.56565657
#
# ##### TOTAL_DATA 5000 #####
#
# ~~Result_A_5000~~
# EarlyStopping! Epoch 106
# Last: 93 	T-Loss: 0.567138 	T-Acc: 0.720222 	V-Loss: 0.552438 	V-Acc: 0.724000
# ## Test phase...
# Final test Loss: 0.660944
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58211443 	Recall: 0.62133333 	Prec: 0.54270186
#
# ~~Result_B_5000~~
# EarlyStopping! Epoch 40
# Last: 27 	T-Loss: 0.643634 	T-Acc: 0.642000 	V-Loss: 0.659300 	V-Acc: 0.606000
# ## Test phase...
# Final test Loss: 0.703260
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46312626 	Recall: 0.70133333 	Prec: 0.45898778
#
# ~~Result_C_5000_0.25~~
# EarlyStopping! Epoch 80
# Last: 67 	T-Loss: 0.586006 	T-Acc: 0.700089 	V-Loss: 0.562734 	V-Acc: 0.744000
# ## Test phase...
# Final test Loss: 0.653437
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58745932 	Recall: 0.62577778 	Prec: 0.54785992
#
# ~~Result_C_5000_0.5~~
# EarlyStopping! Epoch 61
# Last: 48 	T-Loss: 0.599601 	T-Acc: 0.692296 	V-Loss: 0.574361 	V-Acc: 0.748000
# ## Test phase...
# Final test Loss: 0.656330
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.58825039 	Recall: 0.67200000 	Prec: 0.54545455
#
# ~~Result_C_5000_0.75~~
# EarlyStopping! Epoch 86
# Last: 73 	T-Loss: 0.588489 	T-Acc: 0.694476 	V-Loss: 0.562365 	V-Acc: 0.734000
# ## Test phase...
# Final test Loss: 0.635614
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61793106 	Recall: 0.67466667 	Prec: 0.57456472
#
# ~~Result_C_5000_1~~
# EarlyStopping! Epoch 64
# Last: 51 	T-Loss: 0.598946 	T-Acc: 0.691667 	V-Loss: 0.567864 	V-Acc: 0.746000
# ## Test phase...
# Final test Loss: 0.643696
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60387913 	Recall: 0.63733333 	Prec: 0.56412274
#
# ~~Result_C_5000_1.5~~
# EarlyStopping! Epoch 72
# Last: 59 	T-Loss: 0.590560 	T-Acc: 0.696000 	V-Loss: 0.573906 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.638172
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61589027 	Recall: 0.66666667 	Prec: 0.57339450
#
# ~~Result_C_5000_2~~
# EarlyStopping! Epoch 54
# Last: 41 	T-Loss: 0.589247 	T-Acc: 0.697926 	V-Loss: 0.578164 	V-Acc: 0.722000
# ## Test phase...
# Final test Loss: 0.640591
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61171060 	Recall: 0.69866667 	Prec: 0.56587473
#
# ~~Result_C_5000_3~~
# EarlyStopping! Epoch 69
# Last: 56 	T-Loss: 0.575946 	T-Acc: 0.701333 	V-Loss: 0.576022 	V-Acc: 0.708000
# ## Test phase...
# Final test Loss: 0.628074
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63499530 	Recall: 0.71377778 	Prec: 0.58741770
#
# ~~Result_C_5000_4~~
# EarlyStopping! Epoch 50
# Last: 37 	T-Loss: 0.576301 	T-Acc: 0.701200 	V-Loss: 0.586875 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.633956
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62297774 	Recall: 0.73333333 	Prec: 0.57371349
#
# ~~Result_C_5000_5~~
# EarlyStopping! Epoch 53
# Last: 40 	T-Loss: 0.571739 	T-Acc: 0.700111 	V-Loss: 0.583158 	V-Acc: 0.684000
# ## Test phase...
# Final test Loss: 0.635330
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61760550 	Recall: 0.71555556 	Prec: 0.57011331
#
# ~~Result_C_5000_6~~
# EarlyStopping! Epoch 62
# Last: 49 	T-Loss: 0.569620 	T-Acc: 0.704095 	V-Loss: 0.591464 	V-Acc: 0.700000
# ## Test phase...
# Final test Loss: 0.632720
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62142712 	Recall: 0.72888889 	Prec: 0.57262570
#
# ~~Result_C_5000_7~~
# EarlyStopping! Epoch 55
# Last: 42 	T-Loss: 0.561969 	T-Acc: 0.707056 	V-Loss: 0.582505 	V-Acc: 0.666000
# ## Test phase...
# Final test Loss: 0.631488
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62315665 	Recall: 0.73955556 	Prec: 0.57339766
#
# ~~Result_C_5000_8~~
# EarlyStopping! Epoch 46
# Last: 33 	T-Loss: 0.568524 	T-Acc: 0.702840 	V-Loss: 0.605072 	V-Acc: 0.666000
# ## Test phase...
# Final test Loss: 0.642196
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.60221194 	Recall: 0.73955556 	Prec: 0.55503669
#
# ~~Result_C_5000_9~~
# EarlyStopping! Epoch 50
# Last: 37 	T-Loss: 0.563675 	T-Acc: 0.706378 	V-Loss: 0.601215 	V-Acc: 0.658000
# ## Test phase...
# Final test Loss: 0.637074
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61683345 	Recall: 0.77422222 	Prec: 0.56595192
#
# ~~Result_C_5000_10~~
# EarlyStopping! Epoch 28
# Last: 15 	T-Loss: 0.574721 	T-Acc: 0.701091 	V-Loss: 0.615808 	V-Acc: 0.654000
# ## Test phase...
# Final test Loss: 0.664038
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.56673555 	Recall: 0.71200000 	Prec: 0.52662722
#
# ##### TOTAL_DATA 7500 #####
#
# ~~Result_A_7500~~
# EarlyStopping! Epoch 80
# Last: 67 	T-Loss: 0.562454 	T-Acc: 0.722519 	V-Loss: 0.557195 	V-Acc: 0.720000
# ## Test phase...
# Final test Loss: 0.649459
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.59653351 	Recall: 0.63911111 	Prec: 0.55607115
#
# ~~Result_B_7500~~
# EarlyStopping! Epoch 33
# Last: 20 	T-Loss: 0.636642 	T-Acc: 0.657333 	V-Loss: 0.662364 	V-Acc: 0.590667
# ## Test phase...
# Final test Loss: 0.707651
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46130751 	Recall: 0.69155556 	Prec: 0.45657277
#
# ~~Result_C_7500_0.25~~
# EarlyStopping! Epoch 92
# Last: 79 	T-Loss: 0.572685 	T-Acc: 0.707514 	V-Loss: 0.556140 	V-Acc: 0.734667
# ## Test phase...
# Final test Loss: 0.636389
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61740087 	Recall: 0.64622222 	Prec: 0.57790143
#
# ~~Result_C_7500_0.5~~
# EarlyStopping! Epoch 100
# Last: 87 	T-Loss: 0.574774 	T-Acc: 0.705679 	V-Loss: 0.553002 	V-Acc: 0.725333
# ## Test phase...
# Final test Loss: 0.622943
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63969886 	Recall: 0.67555556 	Prec: 0.59842520
#
# ~~Result_C_7500_0.75~~
# EarlyStopping! Epoch 58
# Last: 45 	T-Loss: 0.591836 	T-Acc: 0.692204 	V-Loss: 0.570634 	V-Acc: 0.721333
# ## Test phase...
# Final test Loss: 0.636731
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61836121 	Recall: 0.66666667 	Prec: 0.57603687
#
# ~~Result_C_7500_1~~
# EarlyStopping! Epoch 104
# Last: 91 	T-Loss: 0.576965 	T-Acc: 0.702148 	V-Loss: 0.558243 	V-Acc: 0.716000
# ## Test phase...
# Final test Loss: 0.621274
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64250582 	Recall: 0.67200000 	Prec: 0.60239044
#
# ~~Result_C_7500_1.5~~
# EarlyStopping! Epoch 34
# Last: 21 	T-Loss: 0.605859 	T-Acc: 0.680593 	V-Loss: 0.590359 	V-Acc: 0.710667
# ## Test phase...
# Final test Loss: 0.649254
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.59661139 	Recall: 0.69155556 	Prec: 0.55216466
#
# ~~Result_C_7500_2~~
# EarlyStopping! Epoch 42
# Last: 29 	T-Loss: 0.586600 	T-Acc: 0.699753 	V-Loss: 0.584083 	V-Acc: 0.702667
# ## Test phase...
# Final test Loss: 0.635991
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61629982 	Recall: 0.66222222 	Prec: 0.57440247
#
# ~~Result_C_7500_3~~
# EarlyStopping! Epoch 66
# Last: 53 	T-Loss: 0.573982 	T-Acc: 0.699926 	V-Loss: 0.583025 	V-Acc: 0.696000
# ## Test phase...
# Final test Loss: 0.621917
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64303879 	Recall: 0.70311111 	Prec: 0.59743202
#
# ~~Result_C_7500_4~~
# EarlyStopping! Epoch 61
# Last: 48 	T-Loss: 0.570157 	T-Acc: 0.703763 	V-Loss: 0.584857 	V-Acc: 0.678667
# ## Test phase...
# Final test Loss: 0.621891
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63704733 	Recall: 0.71644444 	Prec: 0.58918129
#
# ~~Result_C_7500_5~~
# EarlyStopping! Epoch 59
# Last: 46 	T-Loss: 0.567909 	T-Acc: 0.704938 	V-Loss: 0.590003 	V-Acc: 0.686667
# ## Test phase...
# Final test Loss: 0.621038
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63809300 	Recall: 0.69866667 	Prec: 0.59276018
#
# ~~Result_C_7500_6~~
# EarlyStopping! Epoch 77
# Last: 64 	T-Loss: 0.560946 	T-Acc: 0.708339 	V-Loss: 0.590100 	V-Acc: 0.673333
# ## Test phase...
# Final test Loss: 0.617663
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64533092 	Recall: 0.72266667 	Prec: 0.59691630
#
# ~~Result_C_7500_7~~
# EarlyStopping! Epoch 44
# Last: 31 	T-Loss: 0.564172 	T-Acc: 0.708389 	V-Loss: 0.600245 	V-Acc: 0.673333
# ## Test phase...
# Final test Loss: 0.630136
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62496352 	Recall: 0.71022222 	Prec: 0.57772957
#
# ~~Result_C_7500_8~~
# EarlyStopping! Epoch 45
# Last: 32 	T-Loss: 0.564002 	T-Acc: 0.704543 	V-Loss: 0.606677 	V-Acc: 0.669333
# ## Test phase...
# Final test Loss: 0.625264
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62915571 	Recall: 0.72800000 	Prec: 0.58002833
#
# ~~Result_C_7500_9~~
# EarlyStopping! Epoch 40
# Last: 27 	T-Loss: 0.561026 	T-Acc: 0.706593 	V-Loss: 0.614194 	V-Acc: 0.652000
# ## Test phase...
# Final test Loss: 0.630094
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62717189 	Recall: 0.76444444 	Prec: 0.57525084
#
# ~~Result_C_7500_10~~
# EarlyStopping! Epoch 47
# Last: 34 	T-Loss: 0.557856 	T-Acc: 0.707421 	V-Loss: 0.596383 	V-Acc: 0.657333
# ## Test phase...
# Final test Loss: 0.628983
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62784516 	Recall: 0.76000000 	Prec: 0.57614555
#
# ##### TOTAL_DATA 12389 #####
#
# ~~Result_A_12389~~
# EarlyStopping! Epoch 78
# Last: 65 	T-Loss: 0.554297 	T-Acc: 0.721983 	V-Loss: 0.548519 	V-Acc: 0.730143
# ## Test phase...
# Final test Loss: 0.642746
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61383226 	Recall: 0.66133333 	Prec: 0.57186779
#
# ~~Result_B_12389~~
# EarlyStopping! Epoch 22
# Last: 9 	T-Loss: 0.641093 	T-Acc: 0.652498 	V-Loss: 0.666529 	V-Acc: 0.587576
# ## Test phase...
# Final test Loss: 0.703954
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.46061115 	Recall: 0.68977778 	Prec: 0.45593420
#
# ~~Result_C_12389_0.25~~
# EarlyStopping! Epoch 80
# Last: 67 	T-Loss: 0.570648 	T-Acc: 0.705386 	V-Loss: 0.549433 	V-Acc: 0.729124
# ## Test phase...
# Final test Loss: 0.630612
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.61917305 	Recall: 0.63288889 	Prec: 0.58217498
#
# ~~Result_C_12389_0.5~~
# EarlyStopping! Epoch 90
# Last: 77 	T-Loss: 0.576780 	T-Acc: 0.706225 	V-Loss: 0.551449 	V-Acc: 0.727088
# ## Test phase...
# Final test Loss: 0.627481
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63520220 	Recall: 0.67466667 	Prec: 0.59343237
#
# ~~Result_C_12389_0.75~~
# EarlyStopping! Epoch 97
# Last: 84 	T-Loss: 0.578181 	T-Acc: 0.701559 	V-Loss: 0.554823 	V-Acc: 0.709776
# ## Test phase...
# Final test Loss: 0.623283
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63558929 	Recall: 0.67200000 	Prec: 0.59433962
#
# ~~Result_C_12389_1~~
# EarlyStopping! Epoch 72
# Last: 59 	T-Loss: 0.573950 	T-Acc: 0.704428 	V-Loss: 0.559394 	V-Acc: 0.717923
# ## Test phase...
# Final test Loss: 0.619056
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64591837 	Recall: 0.68800000 	Prec: 0.60327358
#
# ~~Result_C_12389_1.5~~
# EarlyStopping! Epoch 60
# Last: 47 	T-Loss: 0.572662 	T-Acc: 0.704957 	V-Loss: 0.561991 	V-Acc: 0.708758
# ## Test phase...
# Final test Loss: 0.614965
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.65117173 	Recall: 0.68266667 	Prec: 0.61049285
#
# ~~Result_C_12389_2~~
# EarlyStopping! Epoch 73
# Last: 60 	T-Loss: 0.567588 	T-Acc: 0.704834 	V-Loss: 0.567113 	V-Acc: 0.691446
# ## Test phase...
# Final test Loss: 0.612738
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.65704564 	Recall: 0.71644444 	Prec: 0.61060606
#
# ~~Result_C_12389_3~~
# EarlyStopping! Epoch 56
# Last: 43 	T-Loss: 0.566034 	T-Acc: 0.705286 	V-Loss: 0.579387 	V-Acc: 0.688391
# ## Test phase...
# Final test Loss: 0.618019
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64851785 	Recall: 0.73244444 	Prec: 0.59883721
#
# ~~Result_C_12389_4~~
# EarlyStopping! Epoch 49
# Last: 36 	T-Loss: 0.563545 	T-Acc: 0.704669 	V-Loss: 0.584349 	V-Acc: 0.684318
# ## Test phase...
# Final test Loss: 0.618792
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64096650 	Recall: 0.70311111 	Prec: 0.59518435
#
# ~~Result_C_12389_5~~
# EarlyStopping! Epoch 42
# Last: 29 	T-Loss: 0.562208 	T-Acc: 0.706913 	V-Loss: 0.598447 	V-Acc: 0.674134
# ## Test phase...
# Final test Loss: 0.621752
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63889451 	Recall: 0.72888889 	Prec: 0.58950395
#
# ~~Result_C_12389_6~~
# EarlyStopping! Epoch 58
# Last: 45 	T-Loss: 0.558099 	T-Acc: 0.709329 	V-Loss: 0.597886 	V-Acc: 0.670061
# ## Test phase...
# Final test Loss: 0.617087
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.64120757 	Recall: 0.73777778 	Prec: 0.59074733
#
# ~~Result_C_12389_7~~
# EarlyStopping! Epoch 60
# Last: 47 	T-Loss: 0.557893 	T-Acc: 0.709501 	V-Loss: 0.605399 	V-Acc: 0.663951
# ## Test phase...
# Final test Loss: 0.620399
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63917990 	Recall: 0.75911111 	Prec: 0.58653846
#
# ~~Result_C_12389_8~~
# EarlyStopping! Epoch 52
# Last: 39 	T-Loss: 0.557738 	T-Acc: 0.709277 	V-Loss: 0.608050 	V-Acc: 0.655804
# ## Test phase...
# Final test Loss: 0.627370
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.63154345 	Recall: 0.75555556 	Prec: 0.57980900
#
# ~~Result_C_12389_9~~
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/loss.py:498: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# EarlyStopping! Epoch 30
# Last: 17 	T-Loss: 0.557558 	T-Acc: 0.709282 	V-Loss: 0.612309 	V-Acc: 0.653768
# ## Test phase...
# Final test Loss: 0.629169
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62595343 	Recall: 0.76266667 	Prec: 0.57429719
#
# ~~Result_C_12389_10~~
# EarlyStopping! Epoch 33
# Last: 20 	T-Loss: 0.556212 	T-Acc: 0.710001 	V-Loss: 0.624410 	V-Acc: 0.647658
# ## Test phase...
# Final test Loss: 0.631984
# [Evaluate] Threshold argument set. Using 0.5 as threshold
# [Evaluate] ##MAX##
# THRESHOLD: 0.500 	F1: 0.62227495 	Recall: 0.74933333 	Prec: 0.57191316

# %% [markdown]
# ## Save

# %%
final_result = pd.DataFrame(result_list_final) 
final_result = final_result.sort_values(by=['total_data', 'foreign_mult'])
final_result.to_csv('final_{}_{}_{}_result_combined.csv'.format(INDO_DATA_NAME,
                                                               FOREIGN_DATA_NAME,
                                                               MODEL_NAME),
                        index=False)

# %%
print(final_result.shape)
final_result.head()
# Out:
# (288, 8)
#     type  total_data  seed  foreign_mult  total_foreign_data        f1  \
# 1      B         500     4          -1.0                 500  0.484269
# 97     B         500     5          -1.0                 500  0.479491
# 193    B         500     6          -1.0                 500  0.318254
# 0      A         500     4           0.0                   0  0.483589
# 96     A         500     5           0.0                   0  0.475948
#
#        recall  precision
# 1    0.598222   0.458447
# 97   0.608889   0.456362
# 193  1.000000   0.463535
# 0    0.601778   0.458362
# 96   0.637333   0.457562
